# %% [markdown]
# # CONFIGURAÇÕES INICIAIS
#
# »» Recursos de interesse:
#
# - Markdown: https://www.markdownguide.org/

# %% [markdown]
# ## Diretorias

# %%
#Colocar o path correto
#C:\Users\Paulo B\OneDrive - Universidade de Aveiro\TRABALHO_AULAS\AL20222023\ICD\projeto_ICD2223
path = "C:/Users/Paulo B/OneDrive - Universidade de Aveiro/"

path_projeto_ICD2021 = "TRABALHO_AULAS/AL20212022/ICD_202120221/"

path_dados = path + path_projeto_ICD2021 + "projeto_ICD2021/dados/"

# %% [markdown]
# ## Ativar os módulos de interesse

# %%
import requests
import json

import pickle

import math 
import pandas as pd

# %% [markdown]
# ## Funções auxiliares

# %%
# A função "jprint()" tem como objetivo "imprimir" o json (formato de resposta escolhido / solicitado à API) 
# O formato ".json" é uma linguagem utilizada para representação de dados num formato do tipo "chave-valor" - numa estrutura de dados similar a um "dicionário", 
# disponibilizada na linguagem Python. 
# Os dados, tal como numa base de dados usual, podem ter uma estrutura relacional; é usual que estas relações possam ser representadas num formato
# hierárquico. O formato json é assim compatível com esta representação relacional hierárquica, sendo a navegação entre os diferentes níveis definida pelas chaves, 
# que correspondem aos nós da representação hierárquica em rede dos referidos dados codificados no formato json
# Esta função permite representar a estrutura hierárquica do json, através da "impressão" em formato textual, utilizando tabulações por forma a alinhar as chaves que se encontram
# em cada nível hierárquico

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=6)
    print(text)

# %% [markdown]
# ## Configuração Chave API

# %%
MY_API_KEY = "d0178a452f02df51b64ba796b0b9b4da"
MY_API_KEY
# Out:
# 'd0178a452f02df51b64ba796b0b9b4da'

# %% [markdown]
# # RECOLHA DE DADOS - Parte 1
# Pesquisa e recolha de resultados com a API Scoupus API

# %% [markdown]
# ## Análise exploratória dos resultados de pesquisa

# %% [markdown]
# ### Exploratório: 1. Pesquisa API

# %%
# IMPORTANTE: https://dev.elsevier.com/sc_search_tips.html

user_query = "data mining housing automated valuation model"
cursor = "*"

response = requests.get("https://api.elsevier.com/content/search/scopus",
                    headers={'Accept':'application/json',
                             'X-ELS-APIKey': MY_API_KEY},
                         
                    params={    'query' : user_query,
                                #'count' : 1000,
                                #'start' : "25",
                                #'cursor' : '*',
                        }

                        )

print(response.url)
# Out:
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model

# %% [markdown]
# ### Exploratório: 2. Analisar resultados / resposta API

# %%
print(response.status_code)
# Out:
# 200

# %%
# A simples invocação da resposta da API (em formato json) imprime o contéudo obtido com a respetiva syntaxe json
# No entanto, como facilmente se depreende desta forma é dificil discernir a estrutura hierárquica dos dados e, desta forma, extrair os diferentes dados em cada nível
# por forma a transformar os dados numa estrutura de dados mais amigável (por exemplo, um data.frame da livraria "pandas", que nos é uma estrutura de dados mais familiar
# para manipulação)
results = response.json()
results
# Out:
# {'search-results': {'opensearch:totalResults': '256',
#   'opensearch:startIndex': '0',
#   'opensearch:itemsPerPage': '25',
#   'opensearch:Query': {'@role': 'request',
#    '@searchTerms': 'data mining housing automated valuation model',
#    '@startPage': '0'},
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=data+mining+housing+automated+valuation+model',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'first',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=data+mining+housing+automated+valuation+model',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'next',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=25&count=25&query=data+mining+housing+automated+valuation+model',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'last',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=231&count=25&query=data+mining+housing+automated+valuation+model',
#     '@type': 'application/json'}],
#   'entry': [{'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85141519670'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85141519670?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85141519670&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85141519670&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0957417422021650'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85141519670',
#     'dc:identifier': 'SCOPUS_ID:85141519670',
#     'eid': '2-s2.0-85141519670',
#     'dc:title': 'Automated real estate valuation with machine learning models using property descriptions',
#     'dc:creator': 'Baur K.',
#     'prism:publicationName': 'Expert Systems with Applications',
#     'prism:issn': '09574174',
#     'prism:volume': '213',
#     'prism:pageRange': None,
#     'prism:coverDate': '2023-03-01',
#     'prism:coverDisplayDate': '1 March 2023',
#     'prism:doi': '10.1016/j.eswa.2022.119147',
#     'pii': 'S0957417422021650',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Universität Freiburg',
#       'affiliation-city': 'Freiburg im Breisgau',
#       'affiliation-country': 'Germany'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '119147',
#     'source-id': '24201',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85138774719'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85138774719?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85138774719&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85138774719&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85138774719',
#     'dc:identifier': 'SCOPUS_ID:85138774719',
#     'eid': '2-s2.0-85138774719',
#     'dc:title': 'Predicting Carpark Prices Indices in Hong Kong Using AutoML',
#     'dc:creator': 'Li R.Y.M.',
#     'prism:publicationName': 'CMES - Computer Modeling in Engineering and Sciences',
#     'prism:issn': '15261492',
#     'prism:eIssn': '15261506',
#     'prism:volume': '134',
#     'prism:issueIdentifier': '3',
#     'prism:pageRange': '2247-2282',
#     'prism:coverDate': '2023-01-01',
#     'prism:coverDisplayDate': '2023',
#     'prism:doi': '10.32604/cmes.2022.020930',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Hong Kong Shue Yan University',
#       'affiliation-city': 'Hong Kong',
#       'affiliation-country': 'China'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '28642',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfree2read'},
#       {'$': 'repository'},
#       {'$': 'repositoryam'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Bronze'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85138536850'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85138536850?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85138536850&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85138536850&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85138536850',
#     'dc:identifier': 'SCOPUS_ID:85138536850',
#     'eid': '2-s2.0-85138536850',
#     'dc:title': 'House price prediction using hedonic pricing model and machine learning techniques',
#     'dc:creator': 'Zaki J.',
#     'prism:publicationName': 'Concurrency and Computation: Practice and Experience',
#     'prism:issn': '15320626',
#     'prism:eIssn': '15320634',
#     'prism:volume': '34',
#     'prism:issueIdentifier': '27',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-12-10',
#     'prism:coverDisplayDate': '10 December 2022',
#     'prism:doi': '10.1002/cpe.7342',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Faculty of Engineering',
#       'affiliation-city': 'Mansoura',
#       'affiliation-country': 'Egypt'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': 'e7342',
#     'source-id': '27871',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85135926444'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85135926444?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85135926444&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85135926444&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85135926444',
#     'dc:identifier': 'SCOPUS_ID:85135926444',
#     'eid': '2-s2.0-85135926444',
#     'dc:title': 'Gridded land use data for the conterminous United States 1940–2015',
#     'dc:creator': 'Mc Shane C.',
#     'prism:publicationName': 'Scientific Data',
#     'prism:eIssn': '20524463',
#     'prism:volume': '9',
#     'prism:issueIdentifier': '1',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-12-01',
#     'prism:coverDisplayDate': 'December 2022',
#     'prism:doi': '10.1038/s41597-022-01591-0',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'University of Colorado Boulder',
#       'affiliation-city': 'Boulder',
#       'affiliation-country': 'United States'}],
#     'pubmed-id': '35963932',
#     'prism:aggregationType': 'Journal',
#     'subtype': 'dp',
#     'subtypeDescription': 'Data Paper',
#     'article-number': '493',
#     'source-id': '21100451321',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85141846658'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85141846658?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85141846658&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85141846658&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85141846658',
#     'dc:identifier': 'SCOPUS_ID:85141846658',
#     'eid': '2-s2.0-85141846658',
#     'dc:title': 'DOES MACHINE LEARNING PREDICTION DAMPEN THE INFORMATION ASYMMETRY FOR NON-LOCAL INVESTORS?',
#     'dc:creator': 'Jung J.',
#     'prism:publicationName': 'International Journal of Strategic Property Management',
#     'prism:issn': '1648715X',
#     'prism:eIssn': '16489179',
#     'prism:volume': '26',
#     'prism:issueIdentifier': '5',
#     'prism:pageRange': '345-361',
#     'prism:coverDate': '2022-11-14',
#     'prism:coverDisplayDate': '14 November 2022',
#     'prism:doi': '10.3846/ijspm.2022.17590',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Hanyang University ERICA Campus',
#       'affiliation-city': 'Ansan',
#       'affiliation-country': 'South Korea'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '145664',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85118577889'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85118577889?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85118577889&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85118577889&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85118577889',
#     'dc:identifier': 'SCOPUS_ID:85118577889',
#     'eid': '2-s2.0-85118577889',
#     'dc:title': 'Boosted Tree Ensembles for Artificial Intelligence Based Automated Valuation Models (AI-AVM)',
#     'dc:creator': 'Sing T.F.',
#     'prism:publicationName': 'Journal of Real Estate Finance and Economics',
#     'prism:issn': '08955638',
#     'prism:eIssn': '1573045X',
#     'prism:volume': '65',
#     'prism:issueIdentifier': '4',
#     'prism:pageRange': '649-674',
#     'prism:coverDate': '2022-11-01',
#     'prism:coverDisplayDate': 'November 2022',
#     'prism:doi': '10.1007/s11146-021-09861-1',
#     'citedby-count': '6',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'National University of Singapore',
#       'affiliation-city': 'Singapore City',
#       'affiliation-country': 'Singapore'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '23582',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfree2read'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Bronze'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85140593976'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85140593976?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140593976&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85140593976&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85140593976',
#     'dc:identifier': 'SCOPUS_ID:85140593976',
#     'eid': '2-s2.0-85140593976',
#     'dc:title': "What is policy content and how is the public's policy support? A policy cognition study based on natural language processing and social psychology",
#     'dc:creator': 'Zhou L.',
#     'prism:publicationName': 'Frontiers in Psychology',
#     'prism:eIssn': '16641078',
#     'prism:volume': '13',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-10-04',
#     'prism:coverDisplayDate': '4 October 2022',
#     'prism:doi': '10.3389/fpsyg.2022.941762',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Fudan University',
#       'affiliation-city': 'Shanghai',
#       'affiliation-country': 'China'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '941762',
#     'source-id': '21100216571',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85140933127'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85140933127?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140933127&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85140933127&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85140933127',
#     'dc:identifier': 'SCOPUS_ID:85140933127',
#     'eid': '2-s2.0-85140933127',
#     'dc:title': 'A Review of AI Cloud and Edge Sensors, Methods, and Applications for the Recognition of Emotional, Affective and Physiological States',
#     'dc:creator': 'Kaklauskas A.',
#     'prism:publicationName': 'Sensors',
#     'prism:issn': '14248220',
#     'prism:volume': '22',
#     'prism:issueIdentifier': '20',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-10-01',
#     'prism:coverDisplayDate': 'October 2022',
#     'prism:doi': '10.3390/s22207824',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Vilniaus Gedimino Technikos Universitetas',
#       'affiliation-city': 'Vilnius',
#       'affiliation-country': 'Lithuania'}],
#     'pubmed-id': '36298176',
#     'prism:aggregationType': 'Journal',
#     'subtype': 're',
#     'subtypeDescription': 'Review',
#     'article-number': '7824',
#     'source-id': '130124',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85140709943'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85140709943?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140709943&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85140709943&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85140709943',
#     'dc:identifier': 'SCOPUS_ID:85140709943',
#     'eid': '2-s2.0-85140709943',
#     'dc:title': 'Modern Technologies in the Real Estate Market—Opponents vs. Proponents of Their Use: Does New Category of Value Solve the Problem?',
#     'dc:creator': 'Renigier-Biłozor M.',
#     'prism:publicationName': 'Sustainability (Switzerland)',
#     'prism:eIssn': '20711050',
#     'prism:volume': '14',
#     'prism:issueIdentifier': '20',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-10-01',
#     'prism:coverDisplayDate': 'October 2022',
#     'prism:doi': '10.3390/su142013403',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Uniwersytet Warminsko-Mazurski w Olsztynie',
#       'affiliation-city': '\xa0Olsztyn WM',
#       'affiliation-country': 'Poland'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '13403',
#     'source-id': '21100240100',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85137121263'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85137121263?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85137121263&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85137121263&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0197397522001576'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85137121263',
#     'dc:identifier': 'SCOPUS_ID:85137121263',
#     'eid': '2-s2.0-85137121263',
#     'dc:title': 'An explainable model for the mass appraisal of residences: The application of tree-based Machine Learning algorithms and interpretation of value determinants',
#     'dc:creator': 'Iban M.C.',
#     'prism:publicationName': 'Habitat International',
#     'prism:issn': '01973975',
#     'prism:volume': '128',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-10-01',
#     'prism:coverDisplayDate': 'October 2022',
#     'prism:doi': '10.1016/j.habitatint.2022.102660',
#     'pii': 'S0197397522001576',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Mersin Üniversitesi',
#       'affiliation-city': 'Mersin',
#       'affiliation-country': 'Turkey'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '102660',
#     'source-id': '13760',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85136278214'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85136278214?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85136278214&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85136278214&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0169204622001268'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85136278214',
#     'dc:identifier': 'SCOPUS_ID:85136278214',
#     'eid': '2-s2.0-85136278214',
#     'dc:title': 'Pan-European urban green space dynamics: A view from space between 1990 and 2015',
#     'dc:creator': 'Xu F.',
#     'prism:publicationName': 'Landscape and Urban Planning',
#     'prism:issn': '01692046',
#     'prism:volume': '226',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-10-01',
#     'prism:coverDisplayDate': 'October 2022',
#     'prism:doi': '10.1016/j.landurbplan.2022.104477',
#     'pii': 'S0169204622001268',
#     'citedby-count': '2',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'KU Leuven',
#       'affiliation-city': '3000 Leuven',
#       'affiliation-country': 'Belgium'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '104477',
#     'source-id': '19041',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85136190308'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85136190308?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85136190308&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85136190308&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0966692322001387'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85136190308',
#     'dc:identifier': 'SCOPUS_ID:85136190308',
#     'eid': '2-s2.0-85136190308',
#     'dc:title': 'Revealing the determinants of the intermodal transfer ratio between metro and bus systems considering spatial variations',
#     'dc:creator': 'Wu P.',
#     'prism:publicationName': 'Journal of Transport Geography',
#     'prism:issn': '09666923',
#     'prism:volume': '104',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-10-01',
#     'prism:coverDisplayDate': 'October 2022',
#     'prism:doi': '10.1016/j.jtrangeo.2022.103415',
#     'pii': 'S0966692322001387',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'South China University of Technology',
#       'affiliation-city': 'Guangzhou',
#       'affiliation-country': 'China'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '103415',
#     'source-id': '29295',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherhybridgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Hybrid Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85129185852'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85129185852?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85129185852&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85129185852&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85129185852',
#     'dc:identifier': 'SCOPUS_ID:85129185852',
#     'eid': '2-s2.0-85129185852',
#     'dc:title': 'An analysis of the determinants of office real estate price modelling in Nigeria: using a Delphi approach',
#     'dc:creator': 'Yakub A.R.A.',
#     'prism:publicationName': 'Property Management',
#     'prism:issn': '02637472',
#     'prism:volume': '40',
#     'prism:issueIdentifier': '5',
#     'prism:pageRange': '758-779',
#     'prism:coverDate': '2022-09-29',
#     'prism:coverDisplayDate': '29 September 2022',
#     'prism:doi': '10.1108/PM-08-2021-0060',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Universiti Teknologi Malaysia',
#       'affiliation-city': 'Johor Bahru',
#       'affiliation-country': 'Malaysia'},
#      {'@_fa': 'true',
#       'affilname': 'Hussaini Adamu Federal Polytechnic',
#       'affiliation-city': 'Kazaure',
#       'affiliation-country': 'Nigeria'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '144667',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85138198285'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85138198285?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85138198285&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85138198285&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85138198285',
#     'dc:identifier': 'SCOPUS_ID:85138198285',
#     'eid': '2-s2.0-85138198285',
#     'dc:title': 'The impact of digitalization on the practice of determining economical cadastral valuation',
#     'dc:creator': 'Bykowa E.',
#     'prism:publicationName': 'Frontiers in Energy Research',
#     'prism:eIssn': '2296598X',
#     'prism:volume': '10',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-09-02',
#     'prism:coverDisplayDate': '2 September 2022',
#     'prism:doi': '10.3389/fenrg.2022.982976',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Saint Petersburg Mining University',
#       'affiliation-city': 'Saint Petersburg',
#       'affiliation-country': 'Russian Federation'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '982976',
#     'source-id': '21100786317',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85138491709'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85138491709?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85138491709&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85138491709&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85138491709',
#     'dc:identifier': 'SCOPUS_ID:85138491709',
#     'eid': '2-s2.0-85138491709',
#     'dc:title': 'Improving Real Estate Rental Estimations with Visual Data',
#     'dc:creator': 'Azizi I.',
#     'prism:publicationName': 'Big Data and Cognitive Computing',
#     'prism:eIssn': '25042289',
#     'prism:volume': '6',
#     'prism:issueIdentifier': '3',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-09-01',
#     'prism:coverDisplayDate': 'September 2022',
#     'prism:doi': '10.3390/bdcc6030096',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Université de Lausanne (UNIL)',
#       'affiliation-city': 'Lausanne',
#       'affiliation-country': 'Switzerland'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '96',
#     'source-id': '21101020112',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85133158941'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85133158941?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85133158941&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85133158941&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85133158941',
#     'dc:identifier': 'SCOPUS_ID:85133158941',
#     'eid': '2-s2.0-85133158941',
#     'dc:title': 'VPint: value propagation-based spatial interpolation',
#     'dc:creator': 'Arp L.',
#     'prism:publicationName': 'Data Mining and Knowledge Discovery',
#     'prism:issn': '13845810',
#     'prism:eIssn': '1573756X',
#     'prism:volume': '36',
#     'prism:issueIdentifier': '5',
#     'prism:pageRange': '1647-1678',
#     'prism:coverDate': '2022-09-01',
#     'prism:coverDisplayDate': 'September 2022',
#     'prism:doi': '10.1007/s10618-022-00843-2',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Universiteit Leiden',
#       'affiliation-city': 'Leiden',
#       'affiliation-country': 'Netherlands'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '13579',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherhybridgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Hybrid Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85067403748'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85067403748?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85067403748&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85067403748&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85067403748',
#     'dc:identifier': 'SCOPUS_ID:85067403748',
#     'eid': '2-s2.0-85067403748',
#     'dc:title': 'Within-City Spatial Distribution, Heterogeneity and Diffusion of House Price: Evidence from a Spatiotemporal Index for Beijing',
#     'dc:creator': 'Zhu E.',
#     'prism:publicationName': 'Real Estate Economics',
#     'prism:issn': '10808620',
#     'prism:eIssn': '15406229',
#     'prism:volume': '50',
#     'prism:issueIdentifier': '3',
#     'prism:pageRange': '621-655',
#     'prism:coverDate': '2022-09-01',
#     'prism:coverDisplayDate': 'Autumn (Fall) 2022',
#     'prism:doi': '10.1111/1540-6229.12293',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Tsinghua University',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'source-id': '24900',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85137251326'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85137251326?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85137251326&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85137251326&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85137251326',
#     'dc:identifier': 'SCOPUS_ID:85137251326',
#     'eid': '2-s2.0-85137251326',
#     'dc:title': 'Automation of Negative Infrastructural Externalities Assessment Methods to Determine the Cost of Land Resources Based on the Development of a “Thin Client” Model',
#     'dc:creator': 'Bykowa E.',
#     'prism:publicationName': 'Sustainability (Switzerland)',
#     'prism:eIssn': '20711050',
#     'prism:volume': '14',
#     'prism:issueIdentifier': '15',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-08-01',
#     'prism:coverDisplayDate': 'August 2022',
#     'prism:doi': '10.3390/su14159383',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Saint Petersburg Mining University',
#       'affiliation-city': 'Saint Petersburg',
#       'affiliation-country': 'Russian Federation'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '9383',
#     'source-id': '21100240100',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85131562539'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85131562539?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85131562539&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85131562539&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0264837722002368'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85131562539',
#     'dc:identifier': 'SCOPUS_ID:85131562539',
#     'eid': '2-s2.0-85131562539',
#     'dc:title': 'Modern challenges of property market analysis- homogeneous areas determination',
#     'dc:creator': 'Renigier-Biłozor M.',
#     'prism:publicationName': 'Land Use Policy',
#     'prism:issn': '02648377',
#     'prism:volume': '119',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-08-01',
#     'prism:coverDisplayDate': 'August 2022',
#     'prism:doi': '10.1016/j.landusepol.2022.106209',
#     'pii': 'S0264837722002368',
#     'citedby-count': '2',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Uniwersytet Warminsko-Mazurski w Olsztynie',
#       'affiliation-city': '\xa0Olsztyn WM',
#       'affiliation-country': 'Poland'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '106209',
#     'source-id': '14500',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85129751703'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85129751703?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85129751703&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85129751703&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0264837722001946'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85129751703',
#     'dc:identifier': 'SCOPUS_ID:85129751703',
#     'eid': '2-s2.0-85129751703',
#     'dc:title': 'Improving performance of mass real estate valuation through application of the dataset optimization and Spatially Constrained Multivariate Clustering Analysis',
#     'dc:creator': 'Sisman S.',
#     'prism:publicationName': 'Land Use Policy',
#     'prism:issn': '02648377',
#     'prism:volume': '119',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-08-01',
#     'prism:coverDisplayDate': 'August 2022',
#     'prism:doi': '10.1016/j.landusepol.2022.106167',
#     'pii': 'S0264837722001946',
#     'citedby-count': '1',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Gebze Teknik Üniversitesi',
#       'affiliation-city': 'Kocaeli',
#       'affiliation-country': 'Turkey'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '106167',
#     'source-id': '14500',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85135214921'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85135214921?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85135214921&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85135214921&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85135214921',
#     'dc:identifier': 'SCOPUS_ID:85135214921',
#     'eid': '2-s2.0-85135214921',
#     'dc:title': 'Towards explainable real estate valuation via evolutionary algorithms',
#     'dc:creator': 'Angrick S.',
#     'prism:publicationName': 'GECCO 2022 - Proceedings of the 2022 Genetic and Evolutionary Computation Conference',
#     'prism:isbn': [{'@_fa': 'true', '$': '9781450392372'}],
#     'prism:pageRange': '1130-1138',
#     'prism:coverDate': '2022-07-08',
#     'prism:coverDisplayDate': '8 July 2022',
#     'prism:doi': '10.1145/3512290.3528801',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Hasso-Plattner-Institut für Softwaresystemtechnik GmbH',
#       'affiliation-city': 'Potsdam',
#       'affiliation-country': 'Germany'}],
#     'prism:aggregationType': 'Conference Proceeding',
#     'subtype': 'cp',
#     'subtypeDescription': 'Conference Paper',
#     'source-id': '21101099100',
#     'openaccess': '0',
#     'openaccessFlag': False,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'repository'},
#       {'$': 'repositoryam'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85133654140'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85133654140?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85133654140&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85133654140&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85133654140',
#     'dc:identifier': 'SCOPUS_ID:85133654140',
#     'eid': '2-s2.0-85133654140',
#     'dc:title': 'Application of Artificial Neural Networks in Construction Management: A Scientometric Review',
#     'dc:creator': 'Xu H.',
#     'prism:publicationName': 'Buildings',
#     'prism:eIssn': '20755309',
#     'prism:volume': '12',
#     'prism:issueIdentifier': '7',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-07-01',
#     'prism:coverDisplayDate': 'July 2022',
#     'prism:doi': '10.3390/buildings12070952',
#     'citedby-count': '0',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Sichuan University',
#       'affiliation-city': 'Chengdu',
#       'affiliation-country': 'China'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 're',
#     'subtypeDescription': 'Review',
#     'article-number': '952',
#     'source-id': '26980',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'}, {'$': 'publisherfullgold'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'}, {'$': 'Gold'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85123082516'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85123082516?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85123082516&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85123082516&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0169207021001758'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85123082516',
#     'dc:identifier': 'SCOPUS_ID:85123082516',
#     'eid': '2-s2.0-85123082516',
#     'dc:title': 'Forecasting: theory and practice',
#     'dc:creator': 'Petropoulos F.',
#     'prism:publicationName': 'International Journal of Forecasting',
#     'prism:issn': '01692070',
#     'prism:volume': '38',
#     'prism:issueIdentifier': '3',
#     'prism:pageRange': '705-871',
#     'prism:coverDate': '2022-07-01',
#     'prism:coverDisplayDate': '1 July 2022',
#     'prism:doi': '10.1016/j.ijforecast.2021.11.001',
#     'pii': 'S0169207021001758',
#     'citedby-count': '37',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'University of Bath, School of Management',
#       'affiliation-city': 'Bath',
#       'affiliation-country': 'United Kingdom'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 're',
#     'subtypeDescription': 'Review',
#     'source-id': '22706',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherhybridgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'},
#       {'$': 'repositoryam'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Hybrid Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85131423375'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85131423375?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85131423375&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85131423375&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0964569122002150'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85131423375',
#     'dc:identifier': 'SCOPUS_ID:85131423375',
#     'eid': '2-s2.0-85131423375',
#     'dc:title': 'Appeal of word of mouth: Influences of public opinions and sentiment on ports in corporate choice of import and export trade in the post-COVID-19 era',
#     'dc:creator': 'Yi K.',
#     'prism:publicationName': 'Ocean and Coastal Management',
#     'prism:issn': '09645691',
#     'prism:volume': '225',
#     'prism:pageRange': None,
#     'prism:coverDate': '2022-06-15',
#     'prism:coverDisplayDate': '15 June 2022',
#     'prism:doi': '10.1016/j.ocecoaman.2022.106239',
#     'pii': 'S0964569122002150',
#     'citedby-count': '8',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'East China Jiaotong University',
#       'affiliation-city': 'Nanchang',
#       'affiliation-country': 'China'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'article-number': '106239',
#     'source-id': '28333',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85132206804'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85132206804?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85132206804&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85132206804&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85132206804',
#     'dc:identifier': 'SCOPUS_ID:85132206804',
#     'eid': '2-s2.0-85132206804',
#     'dc:title': 'Interpretable Data-Based Explanations for Fairness Debugging',
#     'dc:creator': 'Pradhan R.',
#     'prism:publicationName': 'Proceedings of the ACM SIGMOD International Conference on Management of Data',
#     'prism:issn': '07308078',
#     'prism:isbn': [{'@_fa': 'true', '$': '9781450392495'}],
#     'prism:pageRange': '247-261',
#     'prism:coverDate': '2022-06-10',
#     'prism:coverDisplayDate': '10 June 2022',
#     'prism:doi': '10.1145/3514221.3517886',
#     'citedby-count': '2',
#     'affiliation': [{'@_fa': 'true',
#       'affilname': 'Purdue University',
#       'affiliation-city': 'West Lafayette',
#       'affiliation-country': 'United States'}],
#     'prism:aggregationType': 'Conference Proceeding',
#     'subtype': 'cp',
#     'subtypeDescription': 'Conference Paper',
#     'source-id': '30611',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfree2read'},
#       {'$': 'repository'},
#       {'$': 'repositoryam'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Bronze'},
#       {'$': 'Green'}]}}]}}

# %%
# Podemos assim invocar a função "jprint" que definimos inicialmente para obtermos uma visualização mais amigável da estrutura de dados codificada no json
# Esta visualização permite-nos ainda identificar a "localização" (na hierarquia) dos dados de interesse e, portanto, as respetivas chaves (que nos permitem
# aceder a esses mesmos dados)
jprint(response.json())
# Out:
# {
#       "search-results": {
#             "entry": [
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Freiburg im Breisgau",
#                                     "affiliation-country": "Germany",
#                                     "affilname": "Universit\u00e4t Freiburg"
#                               }
#                         ],
#                         "article-number": "119147",
#                         "citedby-count": "0",
#                         "dc:creator": "Baur K.",
#                         "dc:identifier": "SCOPUS_ID:85141519670",
#                         "dc:title": "Automated real estate valuation with machine learning models using property descriptions",
#                         "eid": "2-s2.0-85141519670",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85141519670",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85141519670?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85141519670&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85141519670&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0957417422021650",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0957417422021650",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-03-01",
#                         "prism:coverDisplayDate": "1 March 2023",
#                         "prism:doi": "10.1016/j.eswa.2022.119147",
#                         "prism:issn": "09574174",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Expert Systems with Applications",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85141519670",
#                         "prism:volume": "213",
#                         "source-id": "24201",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Hong Kong",
#                                     "affiliation-country": "China",
#                                     "affilname": "Hong Kong Shue Yan University"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Li R.Y.M.",
#                         "dc:identifier": "SCOPUS_ID:85138774719",
#                         "dc:title": "Predicting Carpark Prices Indices in Hong Kong Using AutoML",
#                         "eid": "2-s2.0-85138774719",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfree2read"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Bronze"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85138774719",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85138774719?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85138774719&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85138774719&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2023-01-01",
#                         "prism:coverDisplayDate": "2023",
#                         "prism:doi": "10.32604/cmes.2022.020930",
#                         "prism:eIssn": "15261506",
#                         "prism:issn": "15261492",
#                         "prism:issueIdentifier": "3",
#                         "prism:pageRange": "2247-2282",
#                         "prism:publicationName": "CMES - Computer Modeling in Engineering and Sciences",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85138774719",
#                         "prism:volume": "134",
#                         "source-id": "28642",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Mansoura",
#                                     "affiliation-country": "Egypt",
#                                     "affilname": "Faculty of Engineering"
#                               }
#                         ],
#                         "article-number": "e7342",
#                         "citedby-count": "0",
#                         "dc:creator": "Zaki J.",
#                         "dc:identifier": "SCOPUS_ID:85138536850",
#                         "dc:title": "House price prediction using hedonic pricing model and machine learning techniques",
#                         "eid": "2-s2.0-85138536850",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85138536850",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85138536850?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85138536850&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85138536850&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-12-10",
#                         "prism:coverDisplayDate": "10 December 2022",
#                         "prism:doi": "10.1002/cpe.7342",
#                         "prism:eIssn": "15320634",
#                         "prism:issn": "15320626",
#                         "prism:issueIdentifier": "27",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Concurrency and Computation: Practice and Experience",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85138536850",
#                         "prism:volume": "34",
#                         "source-id": "27871",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Boulder",
#                                     "affiliation-country": "United States",
#                                     "affilname": "University of Colorado Boulder"
#                               }
#                         ],
#                         "article-number": "493",
#                         "citedby-count": "0",
#                         "dc:creator": "Mc Shane C.",
#                         "dc:identifier": "SCOPUS_ID:85135926444",
#                         "dc:title": "Gridded land use data for the conterminous United States 1940\u20132015",
#                         "eid": "2-s2.0-85135926444",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85135926444",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85135926444?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85135926444&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85135926444&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-12-01",
#                         "prism:coverDisplayDate": "December 2022",
#                         "prism:doi": "10.1038/s41597-022-01591-0",
#                         "prism:eIssn": "20524463",
#                         "prism:issueIdentifier": "1",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Scientific Data",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85135926444",
#                         "prism:volume": "9",
#                         "pubmed-id": "35963932",
#                         "source-id": "21100451321",
#                         "subtype": "dp",
#                         "subtypeDescription": "Data Paper"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Ansan",
#                                     "affiliation-country": "South Korea",
#                                     "affilname": "Hanyang University ERICA Campus"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Jung J.",
#                         "dc:identifier": "SCOPUS_ID:85141846658",
#                         "dc:title": "DOES MACHINE LEARNING PREDICTION DAMPEN THE INFORMATION ASYMMETRY FOR NON-LOCAL INVESTORS?",
#                         "eid": "2-s2.0-85141846658",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85141846658",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85141846658?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85141846658&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85141846658&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-11-14",
#                         "prism:coverDisplayDate": "14 November 2022",
#                         "prism:doi": "10.3846/ijspm.2022.17590",
#                         "prism:eIssn": "16489179",
#                         "prism:issn": "1648715X",
#                         "prism:issueIdentifier": "5",
#                         "prism:pageRange": "345-361",
#                         "prism:publicationName": "International Journal of Strategic Property Management",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85141846658",
#                         "prism:volume": "26",
#                         "source-id": "145664",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Singapore City",
#                                     "affiliation-country": "Singapore",
#                                     "affilname": "National University of Singapore"
#                               }
#                         ],
#                         "citedby-count": "6",
#                         "dc:creator": "Sing T.F.",
#                         "dc:identifier": "SCOPUS_ID:85118577889",
#                         "dc:title": "Boosted Tree Ensembles for Artificial Intelligence Based Automated Valuation Models (AI-AVM)",
#                         "eid": "2-s2.0-85118577889",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfree2read"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Bronze"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85118577889",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85118577889?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85118577889&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85118577889&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-11-01",
#                         "prism:coverDisplayDate": "November 2022",
#                         "prism:doi": "10.1007/s11146-021-09861-1",
#                         "prism:eIssn": "1573045X",
#                         "prism:issn": "08955638",
#                         "prism:issueIdentifier": "4",
#                         "prism:pageRange": "649-674",
#                         "prism:publicationName": "Journal of Real Estate Finance and Economics",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85118577889",
#                         "prism:volume": "65",
#                         "source-id": "23582",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Shanghai",
#                                     "affiliation-country": "China",
#                                     "affilname": "Fudan University"
#                               }
#                         ],
#                         "article-number": "941762",
#                         "citedby-count": "0",
#                         "dc:creator": "Zhou L.",
#                         "dc:identifier": "SCOPUS_ID:85140593976",
#                         "dc:title": "What is policy content and how is the public's policy support? A policy cognition study based on natural language processing and social psychology",
#                         "eid": "2-s2.0-85140593976",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85140593976",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85140593976?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140593976&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85140593976&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-10-04",
#                         "prism:coverDisplayDate": "4 October 2022",
#                         "prism:doi": "10.3389/fpsyg.2022.941762",
#                         "prism:eIssn": "16641078",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Frontiers in Psychology",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85140593976",
#                         "prism:volume": "13",
#                         "source-id": "21100216571",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Vilnius",
#                                     "affiliation-country": "Lithuania",
#                                     "affilname": "Vilniaus Gedimino Technikos Universitetas"
#                               }
#                         ],
#                         "article-number": "7824",
#                         "citedby-count": "0",
#                         "dc:creator": "Kaklauskas A.",
#                         "dc:identifier": "SCOPUS_ID:85140933127",
#                         "dc:title": "A Review of AI Cloud and Edge Sensors, Methods, and Applications for the Recognition of Emotional, Affective and Physiological States",
#                         "eid": "2-s2.0-85140933127",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85140933127",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85140933127?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140933127&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85140933127&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-10-01",
#                         "prism:coverDisplayDate": "October 2022",
#                         "prism:doi": "10.3390/s22207824",
#                         "prism:issn": "14248220",
#                         "prism:issueIdentifier": "20",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Sensors",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85140933127",
#                         "prism:volume": "22",
#                         "pubmed-id": "36298176",
#                         "source-id": "130124",
#                         "subtype": "re",
#                         "subtypeDescription": "Review"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "\u00a0Olsztyn WM",
#                                     "affiliation-country": "Poland",
#                                     "affilname": "Uniwersytet Warminsko-Mazurski w Olsztynie"
#                               }
#                         ],
#                         "article-number": "13403",
#                         "citedby-count": "0",
#                         "dc:creator": "Renigier-Bi\u0142ozor M.",
#                         "dc:identifier": "SCOPUS_ID:85140709943",
#                         "dc:title": "Modern Technologies in the Real Estate Market\u2014Opponents vs. Proponents of Their Use: Does New Category of Value Solve the Problem?",
#                         "eid": "2-s2.0-85140709943",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfullgold"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Gold"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85140709943",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85140709943?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85140709943&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85140709943&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-10-01",
#                         "prism:coverDisplayDate": "October 2022",
#                         "prism:doi": "10.3390/su142013403",
#                         "prism:eIssn": "20711050",
#                         "prism:issueIdentifier": "20",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Sustainability (Switzerland)",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85140709943",
#                         "prism:volume": "14",
#                         "source-id": "21100240100",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Mersin",
#                                     "affiliation-country": "Turkey",
#                                     "affilname": "Mersin \u00dcniversitesi"
#                               }
#                         ],
#                         "article-number": "102660",
#                         "citedby-count": "0",
#                         "dc:creator": "Iban M.C.",
#                         "dc:identifier": "SCOPUS_ID:85137121263",
#                         "dc:title": "An explainable model for the mass appraisal of residences: The application of tree-based Machine Learning algorithms and interpretation of value determinants",
#                         "eid": "2-s2.0-85137121263",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85137121263",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85137121263?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85137121263&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85137121263&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0197397522001576",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0197397522001576",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-10-01",
#                         "prism:coverDisplayDate": "October 2022",
#                         "prism:doi": "10.1016/j.habitatint.2022.102660",
#                         "prism:issn": "01973975",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Habitat International",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85137121263",
#                         "prism:volume": "128",
#                         "source-id": "13760",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "3000 Leuven",
#                                     "affiliation-country": "Belgium",
#                                     "affilname": "KU Leuven"
#                               }
#                         ],
#                         "article-number": "104477",
#                         "citedby-count": "2",
#                         "dc:creator": "Xu F.",
#                         "dc:identifier": "SCOPUS_ID:85136278214",
#                         "dc:title": "Pan-European urban green space dynamics: A view from space between 1990 and 2015",
#                         "eid": "2-s2.0-85136278214",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85136278214",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85136278214?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85136278214&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85136278214&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0169204622001268",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0169204622001268",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-10-01",
#                         "prism:coverDisplayDate": "October 2022",
#                         "prism:doi": "10.1016/j.landurbplan.2022.104477",
#                         "prism:issn": "01692046",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Landscape and Urban Planning",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85136278214",
#                         "prism:volume": "226",
#                         "source-id": "19041",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Guangzhou",
#                                     "affiliation-country": "China",
#                                     "affilname": "South China University of Technology"
#                               }
#                         ],
#                         "article-number": "103415",
#                         "citedby-count": "0",
#                         "dc:creator": "Wu P.",
#                         "dc:identifier": "SCOPUS_ID:85136190308",
#                         "dc:title": "Revealing the determinants of the intermodal transfer ratio between metro and bus systems considering spatial variations",
#                         "eid": "2-s2.0-85136190308",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherhybridgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Hybrid Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85136190308",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85136190308?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85136190308&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85136190308&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0966692322001387",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "pii": "S0966692322001387",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-10-01",
#                         "prism:coverDisplayDate": "October 2022",
#                         "prism:doi": "10.1016/j.jtrangeo.2022.103415",
#                         "prism:issn": "09666923",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Journal of Transport Geography",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85136190308",
#                         "prism:volume": "104",
#                         "source-id": "29295",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Johor Bahru",
#                                     "affiliation-country": "Malaysia",
#                                     "affilname": "Universiti Teknologi Malaysia"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Kazaure",
#                                     "affiliation-country": "Nigeria",
#                                     "affilname": "Hussaini Adamu Federal Polytechnic"
#                               }
#                         ],
#                         "citedby-count": "0",
#                         "dc:creator": "Yakub A.R.A.",
#                         "dc:identifier": "SCOPUS_ID:85129185852",
#                         "dc:title": "An analysis of the determinants of office real estate price modelling in Nigeria: using a Delphi approach",
#                         "eid": "2-s2.0-85129185852",
#                         "link": [
#                               {
#                                     "@_fa": "true",
# ...
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85133654140?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85133654140&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85133654140&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-07-01",
#                         "prism:coverDisplayDate": "July 2022",
#                         "prism:doi": "10.3390/buildings12070952",
#                         "prism:eIssn": "20755309",
#                         "prism:issueIdentifier": "7",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Buildings",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85133654140",
#                         "prism:volume": "12",
#                         "source-id": "26980",
#                         "subtype": "re",
#                         "subtypeDescription": "Review"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Bath",
#                                     "affiliation-country": "United Kingdom",
#                                     "affilname": "University of Bath, School of Management"
#                               }
#                         ],
#                         "citedby-count": "37",
#                         "dc:creator": "Petropoulos F.",
#                         "dc:identifier": "SCOPUS_ID:85123082516",
#                         "dc:title": "Forecasting: theory and practice",
#                         "eid": "2-s2.0-85123082516",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherhybridgold"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryvor"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Hybrid Gold"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85123082516",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85123082516?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85123082516&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85123082516&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0169207021001758",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "pii": "S0169207021001758",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-07-01",
#                         "prism:coverDisplayDate": "1 July 2022",
#                         "prism:doi": "10.1016/j.ijforecast.2021.11.001",
#                         "prism:issn": "01692070",
#                         "prism:issueIdentifier": "3",
#                         "prism:pageRange": "705-871",
#                         "prism:publicationName": "International Journal of Forecasting",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85123082516",
#                         "prism:volume": "38",
#                         "source-id": "22706",
#                         "subtype": "re",
#                         "subtypeDescription": "Review"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "Nanchang",
#                                     "affiliation-country": "China",
#                                     "affilname": "East China Jiaotong University"
#                               }
#                         ],
#                         "article-number": "106239",
#                         "citedby-count": "8",
#                         "dc:creator": "Yi K.",
#                         "dc:identifier": "SCOPUS_ID:85131423375",
#                         "dc:title": "Appeal of word of mouth: Influences of public opinions and sentiment on ports in corporate choice of import and export trade in the post-COVID-19 era",
#                         "eid": "2-s2.0-85131423375",
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85131423375",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85131423375?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85131423375&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85131423375&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/article/eid/1-s2.0-S0964569122002150",
#                                     "@ref": "full-text"
#                               }
#                         ],
#                         "openaccess": "0",
#                         "openaccessFlag": false,
#                         "pii": "S0964569122002150",
#                         "prism:aggregationType": "Journal",
#                         "prism:coverDate": "2022-06-15",
#                         "prism:coverDisplayDate": "15 June 2022",
#                         "prism:doi": "10.1016/j.ocecoaman.2022.106239",
#                         "prism:issn": "09645691",
#                         "prism:pageRange": null,
#                         "prism:publicationName": "Ocean and Coastal Management",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85131423375",
#                         "prism:volume": "225",
#                         "source-id": "28333",
#                         "subtype": "ar",
#                         "subtypeDescription": "Article"
#                   },
#                   {
#                         "@_fa": "true",
#                         "affiliation": [
#                               {
#                                     "@_fa": "true",
#                                     "affiliation-city": "West Lafayette",
#                                     "affiliation-country": "United States",
#                                     "affilname": "Purdue University"
#                               }
#                         ],
#                         "citedby-count": "2",
#                         "dc:creator": "Pradhan R.",
#                         "dc:identifier": "SCOPUS_ID:85132206804",
#                         "dc:title": "Interpretable Data-Based Explanations for Fairness Debugging",
#                         "eid": "2-s2.0-85132206804",
#                         "freetoread": {
#                               "value": [
#                                     {
#                                           "$": "all"
#                                     },
#                                     {
#                                           "$": "publisherfree2read"
#                                     },
#                                     {
#                                           "$": "repository"
#                                     },
#                                     {
#                                           "$": "repositoryam"
#                                     }
#                               ]
#                         },
#                         "freetoreadLabel": {
#                               "value": [
#                                     {
#                                           "$": "All Open Access"
#                                     },
#                                     {
#                                           "$": "Bronze"
#                                     },
#                                     {
#                                           "$": "Green"
#                                     }
#                               ]
#                         },
#                         "link": [
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85132206804",
#                                     "@ref": "self"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://api.elsevier.com/content/abstract/scopus_id/85132206804?field=author,affiliation",
#                                     "@ref": "author-affiliation"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85132206804&origin=inward",
#                                     "@ref": "scopus"
#                               },
#                               {
#                                     "@_fa": "true",
#                                     "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85132206804&origin=inward",
#                                     "@ref": "scopus-citedby"
#                               }
#                         ],
#                         "openaccess": "1",
#                         "openaccessFlag": true,
#                         "prism:aggregationType": "Conference Proceeding",
#                         "prism:coverDate": "2022-06-10",
#                         "prism:coverDisplayDate": "10 June 2022",
#                         "prism:doi": "10.1145/3514221.3517886",
#                         "prism:isbn": [
#                               {
#                                     "$": "9781450392495",
#                                     "@_fa": "true"
#                               }
#                         ],
#                         "prism:issn": "07308078",
#                         "prism:pageRange": "247-261",
#                         "prism:publicationName": "Proceedings of the ACM SIGMOD International Conference on Management of Data",
#                         "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85132206804",
#                         "source-id": "30611",
#                         "subtype": "cp",
#                         "subtypeDescription": "Conference Paper"
#                   }
#             ],
#             "link": [
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=0&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "self",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=0&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "first",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=25&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "next",
#                         "@type": "application/json"
#                   },
#                   {
#                         "@_fa": "true",
#                         "@href": "https://api.elsevier.com/content/search/scopus?start=231&count=25&query=data+mining+housing+automated+valuation+model",
#                         "@ref": "last",
#                         "@type": "application/json"
#                   }
#             ],
#             "opensearch:Query": {
#                   "@role": "request",
#                   "@searchTerms": "data mining housing automated valuation model",
#                   "@startPage": "0"
#             },
#             "opensearch:itemsPerPage": "25",
#             "opensearch:startIndex": "0",
#             "opensearch:totalResults": "256"
#       }
# }

# %%
results["search-results"]['entry'][0]["affiliation"]
# Out:
# [{'@_fa': 'true',
#   'affilname': 'Universität Freiburg',
#   'affiliation-city': 'Freiburg im Breisgau',
#   'affiliation-country': 'Germany'}]

# %%
'affiliation' in results["search-results"]['entry'][0]
# Out:
# True

# %% [markdown]
# ### Exploratório: 3. Número total de resultados obtidos na pesquisa

# %%
number_of_articles_retrieved = results["search-results"]["opensearch:totalResults"]
number_of_articles_retrieved
# Out:
# '256'

# %%
number_of_articles_perResultPage = results["search-results"]["opensearch:itemsPerPage"]
number_of_articles_perResultPage
# Out:
# '25'

# %% [markdown]
# ### Exploratório: 4. Obter dados de cada um dos resultados de pesquisa e transformar numa estrutura de dados amigável (pandas -» data.frame )

# %% [markdown]
# #### Opção 1

# %%
df = pd.DataFrame.from_records(results["search-results"]['entry'] )
df[:3]
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 2  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85141519670
# 1  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85138774719
# 2  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85138536850
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85141519670  Automated real estate valuation with machine l...
# 1  2-s2.0-85138774719  Predicting Carpark Prices Indices in Hong Kong...
# 2  2-s2.0-85138536850  House price prediction using hedonic pricing m...
#
#   dc:creator                              prism:publicationName prism:issn  \
# 0    Baur K.                   Expert Systems with Applications   09574174
# 1  Li R.Y.M.  CMES - Computer Modeling in Engineering and Sc...   15261492
# 2    Zaki J.  Concurrency and Computation: Practice and Expe...   15320626
#
#   prism:volume  ... article-number source-id openaccess openaccessFlag  \
# 0          213  ...         119147     24201          0          False
# 1          134  ...            NaN     28642          1           True
# 2           34  ...          e7342     27871          0          False
#
#   prism:eIssn prism:issueIdentifier  \
# 0         NaN                   NaN
# 1    15261506                     3
# 2    15320634                    27
#
#                                           freetoread  \
# 0                                                NaN
# 1  {'value': [{'$': 'all'}, {'$': 'publisherfree2...
# 2                                                NaN
#
#                                      freetoreadLabel pubmed-id prism:isbn
# 0                                                NaN       NaN        NaN
# 1  {'value': [{'$': 'All Open Access'}, {'$': 'Br...       NaN        NaN
# 2                                                NaN       NaN        NaN
#
# [3 rows x 30 columns]

# %% [markdown]
# #### Opção 2

# %%
df = pd.json_normalize(results["search-results"],['entry'] )
df[:3]
# Out:
#    @_fa                                               link  \
# 0  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 1  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
# 2  true  [{'@_fa': 'true', '@ref': 'self', '@href': 'ht...
#
#                                            prism:url          dc:identifier  \
# 0  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85141519670
# 1  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85138774719
# 2  https://api.elsevier.com/content/abstract/scop...  SCOPUS_ID:85138536850
#
#                   eid                                           dc:title  \
# 0  2-s2.0-85141519670  Automated real estate valuation with machine l...
# 1  2-s2.0-85138774719  Predicting Carpark Prices Indices in Hong Kong...
# 2  2-s2.0-85138536850  House price prediction using hedonic pricing m...
#
#   dc:creator                              prism:publicationName prism:issn  \
# 0    Baur K.                   Expert Systems with Applications   09574174
# 1  Li R.Y.M.  CMES - Computer Modeling in Engineering and Sc...   15261492
# 2    Zaki J.  Concurrency and Computation: Practice and Expe...   15320626
#
#   prism:volume  ... article-number source-id openaccess openaccessFlag  \
# 0          213  ...         119147     24201          0          False
# 1          134  ...            NaN     28642          1           True
# 2           34  ...          e7342     27871          0          False
#
#   prism:eIssn prism:issueIdentifier  \
# 0         NaN                   NaN
# 1    15261506                     3
# 2    15320634                    27
#
#                                     freetoread.value  \
# 0                                                NaN
# 1  [{'$': 'all'}, {'$': 'publisherfree2read'}, {'...
# 2                                                NaN
#
#                                freetoreadLabel.value pubmed-id prism:isbn
# 0                                                NaN       NaN        NaN
# 1  [{'$': 'All Open Access'}, {'$': 'Bronze'}, {'...       NaN        NaN
# 2                                                NaN       NaN        NaN
#
# [3 rows x 30 columns]

# %% [markdown]
# ### Exploratório: 5. Aceder a dados em diferentes níveis hierárquicos

# %%
df_affiliation = pd.json_normalize(results["search-results"],['entry', 'affiliation'] )
df_affiliation.columns
#df['prism:doi']
#df_affiliation
# Out:
# Index(['@_fa', 'affilname', 'affiliation-city', 'affiliation-country'], dtype='object')

# %%
df_affiliation[:5]
# Out:
#    @_fa                        affilname      affiliation-city  \
# 0  true             Universität Freiburg  Freiburg im Breisgau
# 1  true    Hong Kong Shue Yan University             Hong Kong
# 2  true           Faculty of Engineering              Mansoura
# 3  true   University of Colorado Boulder               Boulder
# 4  true  Hanyang University ERICA Campus                 Ansan
#
#   affiliation-country
# 0             Germany
# 1               China
# 2               Egypt
# 3       United States
# 4         South Korea

# %% [markdown]
# ### Exploratório: 5.1 Aceder a dados em diferentes níveis hierárquicos »» POSSÍVEIS DIFICULDADES
#
# Por vezes, nos resultados de pesquisa alguns items podem não conter certos elementos / informação codificada em níveis hierárquicos
# inferiores do json.
# Por exemplo, a informação sobre a afiliação dos autores pode estar omissa.
# Nestes casos, ao usar a função "pd.json_normalize" para navegar para níveis inferiores pode devolver um erro e inviabilizar o processo automatizado (isto porque a função
# "json_normalize" não permite uma forma expedita de solucionar este problema).
#
# Uma estratégia "naife" para ultrapassar esta questão passa por  transformar os dados para um data.frame considerando
# apenas o nível inicial da hierarquia do json (ou seja, utilizar a função json_normalize como fizemos para obter o objeto "df" anteriormente).
# Como verificamos, certos elementos do data.frame "df" armazenam dados em formato json / dicionário nas suas células.
# Ao invés de utilizarmos a função "json_normalize" para obtermos dados nos níveis hierárquicos inferiores, podemos desenvolver o nosso próprio algoritmo
# por forma a solucionarmos os problemas de dados omissos.
#
# Assim, uma implementação alternativa do ponto 5, para os dados da coluna "affiliation" seria algo como o que se ilustra no código seguinte.
#
# NOTA: reparem que se optarem por esta estratégia deverão alterar o código da seccção "Automatização global" em conformidade!

# %%
i=0 #devem utilizar um índice (de linha) para o qual existam dados na coluna "affiliation" do vosso data.frame «df»
AFF_COL_NAMES = pd.json_normalize(df.affiliation[0]).columns

df_affiliation_v2 = pd.DataFrame(columns=AFF_COL_NAMES)

for i in range(len(df.affiliation)) :
    if  type(df.affiliation.iloc[i]) == list :
        df_aux = pd.json_normalize(df.affiliation.iloc[i])
        df_affiliation_v2 = df_affiliation_v2.append(df_aux, ignore_index=True)

    else:
        emptydf = pd.DataFrame(np.nan, index=[0],columns=AFF_COL_NAMES) 
        df_affiliation_v2 = df_affiliation_v2.append(emptydf, ignore_index=True)

# %%
df_affiliation_v2[:5]
# Out:
#    @_fa                        affilname      affiliation-city  \
# 0  true             Universität Freiburg  Freiburg im Breisgau
# 1  true    Hong Kong Shue Yan University             Hong Kong
# 2  true           Faculty of Engineering              Mansoura
# 3  true   University of Colorado Boulder               Boulder
# 4  true  Hanyang University ERICA Campus                 Ansan
#
#   affiliation-country
# 0             Germany
# 1               China
# 2               Egypt
# 3       United States
# 4         South Korea

# %% [markdown]
# ### Exploratório: 6. Combinar dados de diferentes hierarquias num único "data.frame"
# https://pandas.pydata.org/docs/getting_started/intro_tutorials/08_combine_dataframes.html

# %%
FIELDS = ['dc:title', "prism:doi", 'dc:creator', 'citedby-count', 'openaccess']
df[FIELDS][:3]
# Out:
#                                             dc:title  \
# 0  Nonlinear public transit accessibility effects...
# 1                   Forecasting: theory and practice
# 2  Rapid Earthquake Loss Estimation Model for Alg...
#
#                           prism:doi      dc:creator citedby-count openaccess
# 0     10.1016/j.tranpol.2022.01.004          Jin T.             0          0
# 1  10.1016/j.ijforecast.2021.11.001  Petropoulos F.             1          1
# 2     10.1080/15583058.2021.1958394       Boukri M.             0          0

# %%
df_all = pd.merge(df[FIELDS], df_affiliation, how='left', left_index=True, right_index=True)
df_all[:3]

# %% [markdown]
# ## Automatização global
# Recolha de resultados individuais da API, seleção de dados de interesse, criação de estrutura de dados amigável

# %%
'entry' in results["search-results"]
# Out:
# True

# %%
user_query = "data mining housing automated valuation model"
LEVEL0_FIELDS_OF_INTEREST = ['dc:title', "prism:doi", 'dc:creator']
AFFILIATION_FIELDS_OF_INTEREST = ['affilname', 'affiliation-city', 'affiliation-country']

df_results_list = pd.DataFrame(columns=LEVEL0_FIELDS_OF_INTEREST+AFFILIATION_FIELDS_OF_INTEREST)

cursor = "*"
start = 0

while start <= int(number_of_articles_retrieved):
    
    
    response = requests.get("https://api.elsevier.com/content/search/scopus",
                    headers={'Accept':'application/json',
                             'X-ELS-APIKey': MY_API_KEY},
                         
                    params={    'query' : user_query,
                                'start' : start
                                #'cursor' : cursor,
                        }

                        )
    print(i)
    print(response.url)
    print(response.status_code)



    if(response.status_code == 200):

        results_aux = response.json()

        df_level1_aux = pd.DataFrame.from_records(results_aux["search-results"]['entry'] )
        df_level1_aux = df_level1_aux[LEVEL0_FIELDS_OF_INTEREST]

        if 'affiliation' in results["search-results"]['entry'][0]:
            
            df_affil_aux = pd.json_normalize(results["search-results"],['entry', 'affiliation'] )
            df_affil_aux = df_affil_aux[AFFILIATION_FIELDS_OF_INTEREST]
            df_all_aux = pd.merge(df_level1_aux, df_affil_aux, how='left', left_index=True, right_index=True)
            df_results_list = df_results_list.append(df_all_aux, ignore_index=True)
            #cursor = results_aux["search-results"]["cursor"]['@next']

        else:

            df_affil_aux = pd.DataFrame(np.nan, index=[0],columns=AFF_COL_NAMES)
            df_all_aux = pd.merge(df_level1_aux, df_affil_aux, how='left', left_index=True, right_index=True)
            df_results_list = df_results_list.append(df_all_aux, ignore_index=True)
            #cursor = results_aux["search-results"]["cursor"]['@next']
    start = start+int(number_of_articles_perResultPage)+1
# Out:
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=0
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=26
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=52
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=78
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=104
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=130
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=156
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=182
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=208
# 200
# 24
# https://api.elsevier.com/content/search/scopus?query=data+mining+housing+automated+valuation+model&start=234
# 200

# %%
df_results_list[:300]
# Out:
#                                               dc:title  \
# 0    Automated real estate valuation with machine l...
# 1    Predicting Carpark Prices Indices in Hong Kong...
# 2    House price prediction using hedonic pricing m...
# 3    Gridded land use data for the conterminous Uni...
# 4    DOES MACHINE LEARNING PREDICTION DAMPEN THE IN...
# ..                                                 ...
# 242         A new approach to spatial analysis in CAMA
# 243  From concept towards reality: Developing the a...
# 244  Lees' Loss Prevention in the Process Industrie...
# 245   Quality function deployment: A literature review
# 246  Predicting spatial patterns of house prices us...
#
#                               prism:doi       dc:creator  \
# 0            10.1016/j.eswa.2022.119147          Baur K.
# 1             10.32604/cmes.2022.020930        Li R.Y.M.
# 2                      10.1002/cpe.7342          Zaki J.
# 3            10.1038/s41597-022-01591-0      Mc Shane C.
# 4              10.3846/ijspm.2022.17590          Jung J.
# ..                                  ...              ...
# 242           10.1108/02637470510631474  González M.A.S.
# 243            10.1144/1470-9236/04-072     Culshaw M.G.
# 244  10.1016/B978-0-7506-7555-0.X5081-6      Mannan M.S.
# 245       10.1016/S0377-2217(02)00178-9        Chan L.K.
# 246             10.1111/1540-6229.00048         Clapp J.
#
#                                              affilname      affiliation-city  \
# 0                                 Universität Freiburg  Freiburg im Breisgau
# 1                        Hong Kong Shue Yan University             Hong Kong
# 2                               Faculty of Engineering              Mansoura
# 3                       University of Colorado Boulder               Boulder
# 4                      Hanyang University ERICA Campus                 Ansan
# ..                                                 ...                   ...
# 242                                Tsinghua University               Beijing
# 243                 Saint Petersburg Mining University      Saint Petersburg
# 244         Uniwersytet Warminsko-Mazurski w Olsztynie            Olsztyn WM
# 245                          Gebze Teknik Üniversitesi               Kocaeli
# 246  Hasso-Plattner-Institut für Softwaresystemtech...               Potsdam
#
#     affiliation-country
# 0               Germany
# 1                 China
# 2                 Egypt
# 3         United States
# 4           South Korea
# ..                  ...
# 242               China
# 243  Russian Federation
# 244              Poland
# 245              Turkey
# 246             Germany
#
# [247 rows x 6 columns]

# %%
df_results_list["prism:doi"]
# Out:
# 0              10.1016/j.eswa.2022.119147
# 1               10.32604/cmes.2022.020930
# 2                        10.1002/cpe.7342
# 3              10.1038/s41597-022-01591-0
# 4                10.3846/ijspm.2022.17590
#                       ...
# 242             10.1108/02637470510631474
# 243              10.1144/1470-9236/04-072
# 244    10.1016/B978-0-7506-7555-0.X5081-6
# 245         10.1016/S0377-2217(02)00178-9
# 246               10.1111/1540-6229.00048
# Name: prism:doi, Length: 247, dtype: object

# %% [markdown]
# # RECOLHA DE DADOS - Parte 2
# Recolha do contéudo dos artigos selecionados com a API Scopus
#
# NOTA: Como facilmente se verifica na [página](https://dev.elsevier.com/api_docs.html) os artigos completos
# estão disponíveis no serviço «ScienceDirect APIs», especificamente na API «Article Retrieval» (documentação [aqui](https://dev.elsevier.com/documentation/ArticleRetrievalAPI.wadl) )

# %% [markdown]
# ## Recolha de artigos completos
# Utilizando o identificador DOI

# %% [markdown]
# ### Análise exploratória

# %%
dois = df_results_list['prism:doi']
dois[:3]
# Out:
# 0    10.1016/j.eswa.2022.119147
# 1     10.32604/cmes.2022.020930
# 2              10.1002/cpe.7342
# Name: prism:doi, dtype: object

# %%
response_article = requests.get("https://api.elsevier.com/content/article/doi/"+dois[2],
                    headers={ 'Accept':'application/json',
                             'X-ELS-APIKey': MY_API_KEY},
                         
                    params={   }

                        )
print(response_article.url)
print(response_article.status_code)
# Out:
# https://api.elsevier.com/content/article/doi/10.1016/j.jobe.2021.102636
# 200

# %%
#jprint(response_article.json())

# %%
type(dois)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Implementação global

# %%
# - a definir -

# %% [markdown]
# ## Recolha de resumos (dos artigos)
#
# Recolha do contéudo dos resumos dos artigos selecionados com a API Scopus (usando o identificador DOI guardado anteriormente)
#
# NOTA: Como facilmente se verifica na [página](https://dev.elsevier.com/api_docs.html) os resumos podem ser obtidos de duas formas:
# * Através do serviço «ScienceDirect APIs» e especificamente da API «Article Retrieval» (documentação [aqui](https://dev.elsevier.com/documentation/ArticleRetrievalAPI.wadl) ) descrita anteriormente
# * Através do serviço «Scopus APIs» (usado anteriormente para fazer a pesquisa) e especificamente da API «Abstract Retrieval» (documentação [aqui](https://dev.elsevier.com/documentation/AbstractRetrievalAPI.wadl))

# %% [markdown]
# ### Análise Exploratória

# %%
dois = df_results_list['prism:doi']

# %%
response_abst = requests.get("https://api.elsevier.com/content/abstract/doi/"+dois[114],
                    headers={#'Accept': 'application/json',
                    'Accept': 'application/json',
                    'X-ELS-APIKey': MY_API_KEY},
                    
                    params={   }
                )
print(response_abst.url)
print(response_abst.status_code)
# Out:
# https://api.elsevier.com/content/abstract/doi/10.1002/9781118280249
# 200

# %%
results_abstr = response_abst.json()
results_abstr
# Out:
# {'abstracts-retrieval-response': {'item': {'ait:process-info': {'ait:status': {'@state': 'update',
#      '@type': 'core',
#      '@stage': 'S300'},
#     'ait:date-delivered': {'@day': '06',
#      '@year': '2020',
#      '@timestamp': '2020-02-06T06:35:05.000005-05:00',
#      '@month': '02'},
#     'ait:date-sort': {'@day': '27', '@year': '2017', '@month': '11'}},
#    'bibrecord': {'head': {'citation-title': 'From the preface to the first edition',
#      'abstracts': None,
#      'citation-info': {'citation-type': {'@code': 'ed'},
#       'citation-language': {'@language': 'English', '@xml:lang': 'eng'}},
#      'source': {'sourcetitle-abbrev': 'Vet. Epidemiol.: Fourth Ed.',
#       'website': {'ce:e-address': {'$': 'http://onlinelibrary.wiley.com/book/10.1002/9781118280249',
#         '@type': 'email'}},
#       '@country': 'usa',
#       'translated-sourcetitle': {'@xml:lang': 'eng'},
#       'volisspag': {'pagerange': {'@first': 'xix'}},
#       '@type': 'b',
#       'publicationyear': {'@first': '2017'},
#       'isbn': [{'@level': 'volume',
#         '$': '9781118280249',
#         '@type': 'electronic',
#         '@length': '13'},
#        {'@level': 'volume',
#         '$': '9781118280287',
#         '@type': 'print',
#         '@length': '13'}],
#       'publisher': {'publishername': 'Wiley Blackwell'},
#       'sourcetitle': 'Veterinary Epidemiology: Fourth Edition',
#       '@srcid': '21100876345',
#       'publicationdate': {'month': '11',
#        'year': '2017',
#        'date-text': {'@xfab-added': 'true', '$': '27 November 2017'},
#        'day': '27'}},
#      'enhancement': {'classificationgroup': {'classifications': [{'@type': 'ASJC',
#          'classification': '3400'},
#         {'@type': 'SUBJABBR', 'classification': 'VETE'}]}}},
#     'item-info': {'copyright': {'$': 'Copyright 2018 Elsevier B.V., All rights reserved.',
#       '@type': 'Elsevier'},
#      'dbcollection': [{'$': 'SNBOOK'}, {'$': 'SCOPUS'}, {'$': 'Scopusbase'}],
#      'history': {'date-created': {'@day': '12',
#        '@year': '2018',
#        '@timestamp': 'BST 07:21:22',
#        '@month': '09'}},
#      'itemidlist': {'itemid': [{'$': '623817463', '@idtype': 'PUI'},
#        {'$': '912609259', '@idtype': 'CAR-ID'},
#        {'$': '2018144867', '@idtype': 'SNBOOK'},
#        {'$': '20182000126919', '@idtype': 'TPB-ID'},
#        {'$': '20181000686349', '@idtype': 'VTW-CAR-ID'},
#        {'$': '85052962587', '@idtype': 'SCP'},
#        {'$': '85052962587', '@idtype': 'SGR'}],
#       'ce:doi': '10.1002/9781118280249'}},
#     'tail': None}},
#   'coredata': {'srctype': 'b',
#    'eid': '2-s2.0-85052962587',
#    'prism:coverDate': '2017-11-27',
#    'prism:aggregationType': 'Book',
#    'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85052962587',
#    'subtypeDescription': 'Editorial',
#    'link': [{'@_fa': 'true',
#      '@rel': 'self',
#      '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85052962587'},
#     {'@_fa': 'true',
#      '@rel': 'scopus',
#      '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052962587&origin=inward'},
#     {'@_fa': 'true',
#      '@rel': 'scopus-citedby',
#      '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85052962587&origin=inward'}],
#    'prism:isbn': [{'$': '9781118280249'}, {'$': '9781118280287'}],
#    'prism:publicationName': 'Veterinary Epidemiology: Fourth Edition',
#    'source-id': '21100876345',
#    'citedby-count': '0',
#    'subtype': 'ed',
#    'dc:title': 'From the preface to the first edition',
#    'openaccess': '0',
#    'openaccessFlag': 'false',
#    'prism:doi': '10.1002/9781118280249',
#    'prism:startingPage': 'xix',
#    'dc:identifier': 'SCOPUS_ID:85052962587',
#    'dc:publisher': 'Wiley Blackwell'},
#   'idxterms': None,
#   'language': {'@xml:lang': 'eng'},
#   'authkeywords': None,
#   'subject-areas': {'subject-area': [{'@_fa': 'true',
#      '$': 'Veterinary (all)',
#      '@code': '3400',
#      '@abbrev': 'VETE'}]},
#   'authors': None}}

# %%
jprint(response_abst.json())
# Out:
# {
#       "abstracts-retrieval-response": {
#             "authkeywords": null,
#             "authors": null,
#             "coredata": {
#                   "citedby-count": "0",
#                   "dc:identifier": "SCOPUS_ID:85052962587",
#                   "dc:publisher": "Wiley Blackwell",
#                   "dc:title": "From the preface to the first edition",
#                   "eid": "2-s2.0-85052962587",
#                   "link": [
#                         {
#                               "@_fa": "true",
#                               "@href": "https://api.elsevier.com/content/abstract/scopus_id/85052962587",
#                               "@rel": "self"
#                         },
#                         {
#                               "@_fa": "true",
#                               "@href": "https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85052962587&origin=inward",
#                               "@rel": "scopus"
#                         },
#                         {
#                               "@_fa": "true",
#                               "@href": "https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85052962587&origin=inward",
#                               "@rel": "scopus-citedby"
#                         }
#                   ],
#                   "openaccess": "0",
#                   "openaccessFlag": "false",
#                   "prism:aggregationType": "Book",
#                   "prism:coverDate": "2017-11-27",
#                   "prism:doi": "10.1002/9781118280249",
#                   "prism:isbn": [
#                         {
#                               "$": "9781118280249"
#                         },
#                         {
#                               "$": "9781118280287"
#                         }
#                   ],
#                   "prism:publicationName": "Veterinary Epidemiology: Fourth Edition",
#                   "prism:startingPage": "xix",
#                   "prism:url": "https://api.elsevier.com/content/abstract/scopus_id/85052962587",
#                   "source-id": "21100876345",
#                   "srctype": "b",
#                   "subtype": "ed",
#                   "subtypeDescription": "Editorial"
#             },
#             "idxterms": null,
#             "item": {
#                   "ait:process-info": {
#                         "ait:date-delivered": {
#                               "@day": "06",
#                               "@month": "02",
#                               "@timestamp": "2020-02-06T06:35:05.000005-05:00",
#                               "@year": "2020"
#                         },
#                         "ait:date-sort": {
#                               "@day": "27",
#                               "@month": "11",
#                               "@year": "2017"
#                         },
#                         "ait:status": {
#                               "@stage": "S300",
#                               "@state": "update",
#                               "@type": "core"
#                         }
#                   },
#                   "bibrecord": {
#                         "head": {
#                               "abstracts": null,
#                               "citation-info": {
#                                     "citation-language": {
#                                           "@language": "English",
#                                           "@xml:lang": "eng"
#                                     },
#                                     "citation-type": {
#                                           "@code": "ed"
#                                     }
#                               },
#                               "citation-title": "From the preface to the first edition",
#                               "enhancement": {
#                                     "classificationgroup": {
#                                           "classifications": [
#                                                 {
#                                                       "@type": "ASJC",
#                                                       "classification": "3400"
#                                                 },
#                                                 {
#                                                       "@type": "SUBJABBR",
#                                                       "classification": "VETE"
#                                                 }
#                                           ]
#                                     }
#                               },
#                               "source": {
#                                     "@country": "usa",
#                                     "@srcid": "21100876345",
#                                     "@type": "b",
#                                     "isbn": [
#                                           {
#                                                 "$": "9781118280249",
#                                                 "@length": "13",
#                                                 "@level": "volume",
#                                                 "@type": "electronic"
#                                           },
#                                           {
#                                                 "$": "9781118280287",
#                                                 "@length": "13",
#                                                 "@level": "volume",
#                                                 "@type": "print"
#                                           }
#                                     ],
#                                     "publicationdate": {
#                                           "date-text": {
#                                                 "$": "27 November 2017",
#                                                 "@xfab-added": "true"
#                                           },
#                                           "day": "27",
#                                           "month": "11",
#                                           "year": "2017"
#                                     },
#                                     "publicationyear": {
#                                           "@first": "2017"
#                                     },
#                                     "publisher": {
#                                           "publishername": "Wiley Blackwell"
#                                     },
#                                     "sourcetitle": "Veterinary Epidemiology: Fourth Edition",
#                                     "sourcetitle-abbrev": "Vet. Epidemiol.: Fourth Ed.",
#                                     "translated-sourcetitle": {
#                                           "@xml:lang": "eng"
#                                     },
#                                     "volisspag": {
#                                           "pagerange": {
#                                                 "@first": "xix"
#                                           }
#                                     },
#                                     "website": {
#                                           "ce:e-address": {
#                                                 "$": "http://onlinelibrary.wiley.com/book/10.1002/9781118280249",
#                                                 "@type": "email"
#                                           }
#                                     }
#                               }
#                         },
#                         "item-info": {
#                               "copyright": {
#                                     "$": "Copyright 2018 Elsevier B.V., All rights reserved.",
#                                     "@type": "Elsevier"
#                               },
#                               "dbcollection": [
#                                     {
#                                           "$": "SNBOOK"
#                                     },
#                                     {
#                                           "$": "SCOPUS"
#                                     },
#                                     {
#                                           "$": "Scopusbase"
#                                     }
#                               ],
#                               "history": {
#                                     "date-created": {
#                                           "@day": "12",
#                                           "@month": "09",
#                                           "@timestamp": "BST 07:21:22",
#                                           "@year": "2018"
#                                     }
#                               },
#                               "itemidlist": {
#                                     "ce:doi": "10.1002/9781118280249",
#                                     "itemid": [
#                                           {
#                                                 "$": "623817463",
#                                                 "@idtype": "PUI"
#                                           },
#                                           {
#                                                 "$": "912609259",
#                                                 "@idtype": "CAR-ID"
#                                           },
#                                           {
#                                                 "$": "2018144867",
#                                                 "@idtype": "SNBOOK"
#                                           },
#                                           {
#                                                 "$": "20182000126919",
#                                                 "@idtype": "TPB-ID"
#                                           },
#                                           {
#                                                 "$": "20181000686349",
#                                                 "@idtype": "VTW-CAR-ID"
#                                           },
#                                           {
#                                                 "$": "85052962587",
#                                                 "@idtype": "SCP"
#                                           },
#                                           {
#                                                 "$": "85052962587",
#                                                 "@idtype": "SGR"
#                                           }
#                                     ]
#                               }
#                         },
#                         "tail": null
#                   }
#             },
#             "language": {
#                   "@xml:lang": "eng"
#             },
#             "subject-areas": {
#                   "subject-area": [
#                         {
#                               "$": "Veterinary (all)",
#                               "@_fa": "true",
#                               "@abbrev": "VETE",
#                               "@code": "3400"
#                         }
#                   ]
#             }
#       }
# }

# %%
resumo = results_abstr["abstracts-retrieval-response"][ "coredata"]['dc:description']
resumo
# Out:
# '© 2021, Emerald Publishing Limited.Purpose: Real estate appraisals are becoming an increasingly important means of backing up financial operations based on the values of these kinds of assets. However, in very large databases, there is a reduction in the predictive capacity when traditional methods, such as multiple linear regression (MLR), are used. This paper aims to determine whether in these cases the application of data mining algorithms can achieve superior statistical results. First, real estate appraisal databases from five towns and cities in the State of Paraná, Brazil, were obtained from Caixa Econômica Federal bank. Design/methodology/approach: After initial validations, additional databases were generated with both real, transformed and nominal values, in clean and raw data. Each was assisted by the application of a wide range of data mining algorithms (multilayer perceptron, support vector regression, K-star, M5Rules and random forest), either isolated or combined (regression by discretization – logistic, bagging and stacking), with the use of 10-fold cross-validation in Weka software. Findings: The results showed more varied incremental statistical results with the use of algorithms than those obtained by MLR, especially when combined algorithms were used. The largest increments were obtained in databases with a large amount of data and in those where minor initial data cleaning was carried out. The paper also conducts a further analysis, including an algorithmic ranking based on the number of significant results obtained. Originality/value: The authors did not find similar studies or research studies conducted in Brazil.'

# %% [markdown]
# ### Implementação Global

# %%
dois = df_results_list['prism:doi']
dois
# Out:
# 0              10.1016/j.eswa.2022.119147
# 1               10.32604/cmes.2022.020930
# 2                        10.1002/cpe.7342
# 3              10.1038/s41597-022-01591-0
# 4                10.3846/ijspm.2022.17590
#                       ...
# 242             10.1108/02637470510631474
# 243              10.1144/1470-9236/04-072
# 244    10.1016/B978-0-7506-7555-0.X5081-6
# 245         10.1016/S0377-2217(02)00178-9
# 246               10.1111/1540-6229.00048
# Name: prism:doi, Length: 247, dtype: object

# %%
abstract_list = []

i=0
for x in dois :
    print(x)
    response_abst = requests.get("https://api.elsevier.com/content/abstract/doi/"+str(x),
                    headers={
                    'Accept': 'application/json',
                    'X-ELS-APIKey': MY_API_KEY},
                    
                    params={   }
                )
    
    print(response_abst.url)
    print(response_abst.status_code)
    print(i)
    i=i+1

    if(response_abst.status_code == 200):
        results_abst = response_abst.json()
        if 'dc:description' in results_abst["abstracts-retrieval-response"][ "coredata"]:
            abstract_list.append( results_abst["abstracts-retrieval-response"][ "coredata"]['dc:description'] )
        else:
            abstract_list.append("NULL")
    else:
        abstract_list.append("NULL")
# Out:
# 10.3390/su132313088
# https://api.elsevier.com/content/abstract/doi/10.3390/su132313088
# 200
# 0
# here
# 10.1186/s40537-021-00476-0
# https://api.elsevier.com/content/abstract/doi/10.1186/s40537-021-00476-0
# 200
# 1
# here
# 10.1016/j.jobe.2021.102636
# https://api.elsevier.com/content/abstract/doi/10.1016/j.jobe.2021.102636
# 200
# 2
# here
# 10.1108/IJHMA-07-2020-0080
# https://api.elsevier.com/content/abstract/doi/10.1108/IJHMA-07-2020-0080
# 200
# 3
# here
# 10.3390/geosciences11110480
# https://api.elsevier.com/content/abstract/doi/10.3390/geosciences11110480
# 200
# 4
# here
# 10.1016/j.landurbplan.2021.104217
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landurbplan.2021.104217
# 200
# 5
# here
# 10.1016/j.jclepro.2021.128824
# https://api.elsevier.com/content/abstract/doi/10.1016/j.jclepro.2021.128824
# 200
# 6
# here
# 10.3390/su132011450
# https://api.elsevier.com/content/abstract/doi/10.3390/su132011450
# 200
# 7
# here
# 10.3390/su132011259
# https://api.elsevier.com/content/abstract/doi/10.3390/su132011259
# 200
# 8
# here
# 10.1007/s12599-021-00715-x
# https://api.elsevier.com/content/abstract/doi/10.1007/s12599-021-00715-x
# 200
# 9
# here
# 10.1016/j.landurbplan.2021.104167
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landurbplan.2021.104167
# 200
# 10
# here
# 10.1016/j.jocm.2021.100303
# https://api.elsevier.com/content/abstract/doi/10.1016/j.jocm.2021.100303
# 200
# 11
# here
# 10.1016/j.ufug.2021.127233
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ufug.2021.127233
# 200
# 12
# here
# 10.1016/j.techfore.2021.120794
# https://api.elsevier.com/content/abstract/doi/10.1016/j.techfore.2021.120794
# 200
# 13
# here
# 10.3390/en14144078
# https://api.elsevier.com/content/abstract/doi/10.3390/en14144078
# 200
# 14
# here
# 10.1016/j.ufug.2021.127172
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ufug.2021.127172
# 200
# 15
# here
# 10.1177/2399808320947729
# https://api.elsevier.com/content/abstract/doi/10.1177/2399808320947729
# 200
# 16
# here
# 10.1177/2399808320938796
# https://api.elsevier.com/content/abstract/doi/10.1177/2399808320938796
# 200
# 17
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 18
# 10.3390/su13116260
# https://api.elsevier.com/content/abstract/doi/10.3390/su13116260
# 200
# 19
# here
# 10.4324/9781003193951
# https://api.elsevier.com/content/abstract/doi/10.4324/9781003193951
# 200
# 20
# here
# 10.1007/s00521-020-05469-3
# https://api.elsevier.com/content/abstract/doi/10.1007/s00521-020-05469-3
# 200
# 21
# here
# 10.3390/land10040388
# https://api.elsevier.com/content/abstract/doi/10.3390/land10040388
# 200
# 22
# here
# 10.11834/jrs.20211018
# https://api.elsevier.com/content/abstract/doi/10.11834/jrs.20211018
# 200
# 23
# here
# 10.1080/00396265.2021.1996797
# https://api.elsevier.com/content/abstract/doi/10.1080/00396265.2021.1996797
# 200
# 24
# here
# 10.1007/s11146-021-09861-1
# https://api.elsevier.com/content/abstract/doi/10.1007/s11146-021-09861-1
# 200
# 25
# here
# 10.1007/s41324-021-00416-3
# https://api.elsevier.com/content/abstract/doi/10.1007/s41324-021-00416-3
# 200
# 26
# here
# 10.1002/widm.1435
# https://api.elsevier.com/content/abstract/doi/10.1002/widm.1435
# 200
# 27
# here
# 10.1007/978-3-030-86973-1_6
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-86973-1_6
# 200
# 28
# here
# 10.1080/15623599.2021.1975021
# https://api.elsevier.com/content/abstract/doi/10.1080/15623599.2021.1975021
# 200
# 29
# here
# 10.1007/s10901-021-09885-2
# https://api.elsevier.com/content/abstract/doi/10.1007/s10901-021-09885-2
# 200
# 30
# here
# 10.1007/s11146-021-09834-4
# https://api.elsevier.com/content/abstract/doi/10.1007/s11146-021-09834-4
# 200
# 31
# here
# 10.1108/JEDT-12-2020-0524
# https://api.elsevier.com/content/abstract/doi/10.1108/JEDT-12-2020-0524
# 200
# 32
# here
# 10.1108/PM-10-2020-0067
# https://api.elsevier.com/content/abstract/doi/10.1108/PM-10-2020-0067
# 200
# 33
# here
# 10.18335/region.v8i1.328
# https://api.elsevier.com/content/abstract/doi/10.18335/region.v8i1.328
# 200
# 34
# here
# 10.3390/land10060566
# https://api.elsevier.com/content/abstract/doi/10.3390/land10060566
# 200
# 35
# here
# 10.1108/SASBE-02-2021-0022
# https://api.elsevier.com/content/abstract/doi/10.1108/SASBE-02-2021-0022
# 200
# 36
# here
# 10.1080/09599916.2020.1858937
# https://api.elsevier.com/content/abstract/doi/10.1080/09599916.2020.1858937
# 200
# 37
# here
# 10.1007/s10901-021-09833-0
# https://api.elsevier.com/content/abstract/doi/10.1007/s10901-021-09833-0
# 200
# 38
# here
# 10.5659/JAIK.2021.37.1.191
# https://api.elsevier.com/content/abstract/doi/10.5659/JAIK.2021.37.1.191
# 200
# 39
# here
# 10.1111/gean.12283
# https://api.elsevier.com/content/abstract/doi/10.1111/gean.12283
# 200
# 40
# here
# 10.1007/978-3-030-48279-4_114
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-48279-4_114
# 200
# 41
# here
# 10.1007/978-3-030-48279-4_132
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-48279-4_132
# 200
# 42
# here
# 10.1007/978-3-030-49579-4_6
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-49579-4_6
# 200
# 43
# here
# 10.1016/j.landusepol.2020.104938
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landusepol.2020.104938
# 200
# 44
# here
# 10.1080/00396265.2020.1771967
# https://api.elsevier.com/content/abstract/doi/10.1080/00396265.2020.1771967
# 200
# 45
# here
# 10.3390/s20236825
# https://api.elsevier.com/content/abstract/doi/10.3390/s20236825
# 200
# 46
# here
# 10.1016/j.landusepol.2020.105070
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landusepol.2020.105070
# 200
# 47
# here
# 10.1109/UV50937.2020.9426215
# https://api.elsevier.com/content/abstract/doi/10.1109/UV50937.2020.9426215
# 200
# 48
# here
# 10.3390/land9100357
# https://api.elsevier.com/content/abstract/doi/10.3390/land9100357
# 200
# 49
# here
# 10.3390/SU12197904
# https://api.elsevier.com/content/abstract/doi/10.3390/SU12197904
# 200
# 50
# here
# 10.1080/09599916.2020.1807587
# https://api.elsevier.com/content/abstract/doi/10.1080/09599916.2020.1807587
# 200
# 51
# here
# 10.1016/j.neucom.2020.05.013
# https://api.elsevier.com/content/abstract/doi/10.1016/j.neucom.2020.05.013
# 200
# 52
# here
# 10.3390/SYM12091549
# https://api.elsevier.com/content/abstract/doi/10.3390/SYM12091549
# 200
# 53
# here
# 10.3390/en13184843
# https://api.elsevier.com/content/abstract/doi/10.3390/en13184843
# 200
# 54
# here
# 10.3390/su12187546
# https://api.elsevier.com/content/abstract/doi/10.3390/su12187546
# 200
# 55
# here
# 10.12011/1000-6788-2020-0027-34
# https://api.elsevier.com/content/abstract/doi/10.12011/1000-6788-2020-0027-34
# 200
# 56
# here
# 10.3390/su12145836
# https://api.elsevier.com/content/abstract/doi/10.3390/su12145836
# 200
# 57
# here
# 10.3390/su12145679
# https://api.elsevier.com/content/abstract/doi/10.3390/su12145679
# 200
# 58
# here
# 10.1108/JPIF-09-2019-0131
# https://api.elsevier.com/content/abstract/doi/10.1108/JPIF-09-2019-0131
# 200
# 59
# here
# 10.1515/remav-2020-0015
# https://api.elsevier.com/content/abstract/doi/10.1515/remav-2020-0015
# 200
# 60
# here
# 10.3390/LAND9050143
# https://api.elsevier.com/content/abstract/doi/10.3390/LAND9050143
# 200
# 61
# here
# 10.3390/su12072899
# https://api.elsevier.com/content/abstract/doi/10.3390/su12072899
# 200
# 62
# here
# 10.1007/s00521-018-3938-7
# https://api.elsevier.com/content/abstract/doi/10.1007/s00521-018-3938-7
# 200
# 63
# here
# 10.1002/sam.11440
# https://api.elsevier.com/content/abstract/doi/10.1002/sam.11440
# 200
# 64
# here
# 10.1007/s11146-019-09724-w
# https://api.elsevier.com/content/abstract/doi/10.1007/s11146-019-09724-w
# 200
# 65
# here
# 10.4324/9780429430015
# https://api.elsevier.com/content/abstract/doi/10.4324/9780429430015
# 200
# 66
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 67
# 10.3390/ijfs8020036
# https://api.elsevier.com/content/abstract/doi/10.3390/ijfs8020036
# 200
# 68
# here
# 10.1007/978-3-030-33157-3_17
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-030-33157-3_17
# 200
# 69
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 70
# 10.31838/jcr.07.11.88
# https://api.elsevier.com/content/abstract/doi/10.31838/jcr.07.11.88
# 200
# 71
# here
# 10.1109/SSCI44817.2019.9002904
# https://api.elsevier.com/content/abstract/doi/10.1109/SSCI44817.2019.9002904
# 200
# 72
# here
# 10.3390/su11247006
# https://api.elsevier.com/content/abstract/doi/10.3390/su11247006
# 200
# 73
# here
# 10.3390/rs11243047
# https://api.elsevier.com/content/abstract/doi/10.3390/rs11243047
# 200
# 74
# here
# 10.1088/1742-6596/1353/1/012139
# https://api.elsevier.com/content/abstract/doi/10.1088/1742-6596/1353/1/012139
# 200
# 75
# here
# 10.1007/s11042-019-07895-5
# https://api.elsevier.com/content/abstract/doi/10.1007/s11042-019-07895-5
# 200
# 76
# here
# 10.1007/s10994-018-5769-2
# https://api.elsevier.com/content/abstract/doi/10.1007/s10994-018-5769-2
# 200
# 77
# here
# 10.1016/j.trip.2019.100028
# https://api.elsevier.com/content/abstract/doi/10.1016/j.trip.2019.100028
# 200
# 78
# here
# 10.2478/remav-2019-0030
# https://api.elsevier.com/content/abstract/doi/10.2478/remav-2019-0030
# 200
# 79
# here
# 10.3390/su11184896
# https://api.elsevier.com/content/abstract/doi/10.3390/su11184896
# 200
# 80
# here
# 10.1016/j.landusepol.2019.104021
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landusepol.2019.104021
# 200
# 81
# here
# 10.1016/j.physrep.2019.05.002
# https://api.elsevier.com/content/abstract/doi/10.1016/j.physrep.2019.05.002
# 200
# 82
# here
# 10.3390/su11133575
# https://api.elsevier.com/content/abstract/doi/10.3390/su11133575
# 200
# 83
# here
# 10.3390/su11133731
# https://api.elsevier.com/content/abstract/doi/10.3390/su11133731
# 200
# 84
# here
# 10.1108/CI-03-2018-0013
# https://api.elsevier.com/content/abstract/doi/10.1108/CI-03-2018-0013
# 200
# 85
# here
# 10.3390/su11113110
# https://api.elsevier.com/content/abstract/doi/10.3390/su11113110
# 200
# 86
# here
# 10.3390/ijgi8040195
# https://api.elsevier.com/content/abstract/doi/10.3390/ijgi8040195
# 200
# 87
# here
# 10.1108/JERER-08-2018-0035
# https://api.elsevier.com/content/abstract/doi/10.1108/JERER-08-2018-0035
# 200
# 88
# here
# 10.1108/ECAM-02-2018-0045
# https://api.elsevier.com/content/abstract/doi/10.1108/ECAM-02-2018-0045
# 200
# 89
# here
# 10.1109/DSAA.2018.00043
# https://api.elsevier.com/content/abstract/doi/10.1109/DSAA.2018.00043
# 200
# 90
# here
# 10.1017/9781108183062
# https://api.elsevier.com/content/abstract/doi/10.1017/9781108183062
# 200
# 91
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 92
# 10.1111/1540-6229.12293
# https://api.elsevier.com/content/abstract/doi/10.1111/1540-6229.12293
# 200
# 93
# here
# 10.1007/978-981-13-6661-1_13
# https://api.elsevier.com/content/abstract/doi/10.1007/978-981-13-6661-1_13
# 200
# 94
# here
# 10.1007/978-3-319-72434-8_11
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-72434-8_11
# 200
# 95
# here
# 10.1007/978-3-319-92099-3_25
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-92099-3_25
# 200
# 96
# here
# 10.1007/978-3-319-92099-3_17
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-92099-3_17
# 200
# 97
# here
# 10.1007/978-3-319-92099-3_46
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-92099-3_46
# 200
# 98
# here
# 10.1186/s40663-018-0146-y
# https://api.elsevier.com/content/abstract/doi/10.1186/s40663-018-0146-y
# 200
# 99
# here
# 10.1186/s40537-018-0154-3
# https://api.elsevier.com/content/abstract/doi/10.1186/s40537-018-0154-3
# 200
# 100
# here
# 10.1002/9781119241072
# https://api.elsevier.com/content/abstract/doi/10.1002/9781119241072
# 200
# 101
# here
# 10.1007/s12652-017-0508-2
# https://api.elsevier.com/content/abstract/doi/10.1007/s12652-017-0508-2
# 200
# 102
# here
# 10.1108/JPIF-10-2017-0067
# https://api.elsevier.com/content/abstract/doi/10.1108/JPIF-10-2017-0067
# 200
# 103
# here
# 10.1061/(ASCE)UP.1943-5444.0000457
# https://api.elsevier.com/content/abstract/doi/10.1061/(ASCE)UP.1943-5444.0000457
# 200
# 104
# here
# 10.3390/su10093085
# https://api.elsevier.com/content/abstract/doi/10.3390/su10093085
# 200
# 105
# here
# 10.1108/IJHMA-02-2017-0021
# https://api.elsevier.com/content/abstract/doi/10.1108/IJHMA-02-2017-0021
# 200
# 106
# here
# 10.1007/s12517-018-3474-x
# https://api.elsevier.com/content/abstract/doi/10.1007/s12517-018-3474-x
# 200
# 107
# here
# 10.1515/jisys-2016-0100
# https://api.elsevier.com/content/abstract/doi/10.1515/jisys-2016-0100
# 200
# 108
# here
# 10.1007/s40518-018-0098-4
# https://api.elsevier.com/content/abstract/doi/10.1007/s40518-018-0098-4
# 200
# 109
# here
# 10.1016/C2017-0-00713-9
# https://api.elsevier.com/content/abstract/doi/10.1016/C2017-0-00713-9
# 200
# 110
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 111
# 10.1504/IJBIDM.2018.094981
# https://api.elsevier.com/content/abstract/doi/10.1504/IJBIDM.2018.094981
# 200
# 112
# here
# 10.1007/978-3-319-98443-8_49
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-98443-8_49
# 200
# 113
# here
# 10.1002/9781118280249
# https://api.elsevier.com/content/abstract/doi/10.1002/9781118280249
# 200
# 114
# 10.3390/su9112138
# https://api.elsevier.com/content/abstract/doi/10.3390/su9112138
# 200
# 115
# here
# 10.4324/9781315602110
# https://api.elsevier.com/content/abstract/doi/10.4324/9781315602110
# 200
# 116
# here
# 10.3390/en10101587
# https://api.elsevier.com/content/abstract/doi/10.3390/en10101587
# 200
# 117
# here
# 10.1007/s10472-016-9534-6
# https://api.elsevier.com/content/abstract/doi/10.1007/s10472-016-9534-6
# 200
# 118
# here
# 10.1002/9781119073666
# https://api.elsevier.com/content/abstract/doi/10.1002/9781119073666
# 200
# 119
# here
# 10.1007/s40171-017-0159-3
# https://api.elsevier.com/content/abstract/doi/10.1007/s40171-017-0159-3
# 200
# 120
# here
# 10.3846/1648715X.2016.1259190
# https://api.elsevier.com/content/abstract/doi/10.3846/1648715X.2016.1259190
# 200
# 121
# here
# 10.3390/su9060909
# https://api.elsevier.com/content/abstract/doi/10.3390/su9060909
# 200
# 122
# here
# 10.1201/9781315155258
# https://api.elsevier.com/content/abstract/doi/10.1201/9781315155258
# 200
# 123
# here
# 10.1108/ECAM-06-2016-0139
# https://api.elsevier.com/content/abstract/doi/10.1108/ECAM-06-2016-0139
# 200
# 124
# here
# 10.1007/978-3-319-62398-6_14
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-62398-6_14
# 200
# 125
# here
# 10.1016/j.rser.2017.04.018
# https://api.elsevier.com/content/abstract/doi/10.1016/j.rser.2017.04.018
# 200
# 126
# here
# 10.1007/978-3-319-48308-5_19
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-48308-5_19
# 200
# 127
# here
# 10.1109/DSAA.2016.58
# https://api.elsevier.com/content/abstract/doi/10.1109/DSAA.2016.58
# 200
# 128
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 129
# 10.1145/2897165
# https://api.elsevier.com/content/abstract/doi/10.1145/2897165
# 200
# 130
# here
# 10.1109/ICSC.2016.85
# https://api.elsevier.com/content/abstract/doi/10.1109/ICSC.2016.85
# 200
# 131
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 132
# 10.1142/9789813146976_0102
# https://api.elsevier.com/content/abstract/doi/10.1142/9789813146976_0102
# 200
# 133
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 134
# 10.1007/978-3-319-42085-1_14
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-42085-1_14
# 200
# 135
# here
# 10.1007/s10640-014-9874-9
# https://api.elsevier.com/content/abstract/doi/10.1007/s10640-014-9874-9
# 200
# 136
# here
# 10.3390/su8010037
# https://api.elsevier.com/content/abstract/doi/10.3390/su8010037
# 200
# 137
# here
# 10.1016/j.envsoft.2015.07.012
# https://api.elsevier.com/content/abstract/doi/10.1016/j.envsoft.2015.07.012
# 200
# 138
# here
# 10.1080/1331677X.2015.1075139
# https://api.elsevier.com/content/abstract/doi/10.1080/1331677X.2015.1075139
# 200
# 139
# here
# 10.1145/2783258.2783383
# https://api.elsevier.com/content/abstract/doi/10.1145/2783258.2783383
# 200
# 140
# here
# 10.1016/j.habitatint.2015.01.017
# https://api.elsevier.com/content/abstract/doi/10.1016/j.habitatint.2015.01.017
# 200
# 141
# here
# 10.1002/9781119009405
# https://api.elsevier.com/content/abstract/doi/10.1002/9781119009405
# 200
# 142
# here
# 10.1201/b19769
# https://api.elsevier.com/content/abstract/doi/10.1201/b19769
# 200
# 143
# here
# 10.1007/978-3-319-24306-1_55
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-319-24306-1_55
# 200
# 144
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 145
# 10.17580/gzh.2015.08.21
# https://api.elsevier.com/content/abstract/doi/10.17580/gzh.2015.08.21
# 200
# 146
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 147
# 10.2495/SC140111
# https://api.elsevier.com/content/abstract/doi/10.2495/SC140111
# 200
# 148
# here
# 10.1109/ICDM.2014.18
# https://api.elsevier.com/content/abstract/doi/10.1109/ICDM.2014.18
# 200
# 149
# here
# 10.1080/10919392.2014.866505
# https://api.elsevier.com/content/abstract/doi/10.1080/10919392.2014.866505
# 200
# 150
# here
# 10.4324/9780203109571
# https://api.elsevier.com/content/abstract/doi/10.4324/9780203109571
# 200
# 151
# here
# 10.1007/978-3-642-40495-5_38
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-642-40495-5_38
# 200
# 152
# here
# 10.4018/978-1-4666-4309-3.ch013
# https://api.elsevier.com/content/abstract/doi/10.4018/978-1-4666-4309-3.ch013
# 200
# 153
# here
# 10.1108/IJHMA-08-2012-0039
# https://api.elsevier.com/content/abstract/doi/10.1108/IJHMA-08-2012-0039
# 200
# 154
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 155
# 10.1016/j.landurbplan.2012.09.008
# https://api.elsevier.com/content/abstract/doi/10.1016/j.landurbplan.2012.09.008
# 200
# 156
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 157
# 10.1504/IJECRM.2013.060697
# https://api.elsevier.com/content/abstract/doi/10.1504/IJECRM.2013.060697
# 200
# 158
# here
# 10.1080/10643389.2012.671097
# https://api.elsevier.com/content/abstract/doi/10.1080/10643389.2012.671097
# 200
# 159
# here
# 10.1016/j.dss.2012.10.038
# https://api.elsevier.com/content/abstract/doi/10.1016/j.dss.2012.10.038
# 200
# 160
# here
# 10.1016/C2009-0-24104-3
# https://api.elsevier.com/content/abstract/doi/10.1016/C2009-0-24104-3
# 200
# 161
# here
# 10.1016/j.ijpe.2012.03.036
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ijpe.2012.03.036
# 200
# 162
# here
# 10.1016/j.ins.2011.07.012
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ins.2011.07.012
# 200
# 163
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 164
# 10.1504/IJBIS.2010.035744
# https://api.elsevier.com/content/abstract/doi/10.1504/IJBIS.2010.035744
# 200
# 165
# here
# 10.1007/978-3-642-03958-4_29
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-642-03958-4_29
# 200
# 166
# here
# 10.1109/ACIIDS.2009.46
# https://api.elsevier.com/content/abstract/doi/10.1109/ACIIDS.2009.46
# 200
# 167
# here
# 10.1002/9781444301021.ch9
# https://api.elsevier.com/content/abstract/doi/10.1002/9781444301021.ch9
# 200
# 168
# 10.1017/CBO9781107477971
# https://api.elsevier.com/content/abstract/doi/10.1017/CBO9781107477971
# 200
# 169
# here
# 10.1007/978-3-642-04441-0_70
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-642-04441-0_70
# 200
# 170
# here
# 10.1007/978-3-642-04441-0_73
# https://api.elsevier.com/content/abstract/doi/10.1007/978-3-642-04441-0_73
# 200
# 171
# here
# 10.1109/HIS.2008.78
# https://api.elsevier.com/content/abstract/doi/10.1109/HIS.2008.78
# 200
# 172
# here
# 10.3233/978-1-58603-904-2-125
# https://api.elsevier.com/content/abstract/doi/10.3233/978-1-58603-904-2-125
# 200
# 173
# here
# nan
# https://api.elsevier.com/content/abstract/doi/nan
# 404
# 174
# 10.1017/CBO9780511546013
# https://api.elsevier.com/content/abstract/doi/10.1017/CBO9780511546013
# 200
# 175
# here
# 10.1016/j.ecolecon.2005.10.005
# https://api.elsevier.com/content/abstract/doi/10.1016/j.ecolecon.2005.10.005
# 200
# 176
# here
# 10.1108/02637470610643092
# https://api.elsevier.com/content/abstract/doi/10.1108/02637470610643092
# 200
# 177
# here
# 10.1016/j.jue.2005.10.003
# https://api.elsevier.com/content/abstract/doi/10.1016/j.jue.2005.10.003
# 200
# 178
# here
# 10.1108/02637470510631474
# https://api.elsevier.com/content/abstract/doi/10.1108/02637470510631474
# 200
# 179
# here
# 10.1144/1470-9236/04-072
# https://api.elsevier.com/content/abstract/doi/10.1144/1470-9236/04-072
# 200
# 180
# here
# 10.1016/B978-0-7506-7555-0.X5081-6
# https://api.elsevier.com/content/abstract/doi/10.1016/B978-0-7506-7555-0.X5081-6
# 504
# 181
# 10.1016/S0377-2217(02)00178-9
# https://api.elsevier.com/content/abstract/doi/10.1016/S0377-2217(02)00178-9
# 200
# 182
# here
# 10.1111/1540-6229.00048
# https://api.elsevier.com/content/abstract/doi/10.1111/1540-6229.00048
# 200
# 183
# here

# %%
abstract_list[0]
# Out:
# '© 2021 by the authors. Licensee MDPI, Basel, Switzerland.The accurate estimation of real estate value helps the development of real estate policies that can respond to the complexities and instability of the real estate market. Previously, statistical methods were used to estimate real estate value, but machine learning methods have gained popularity because their predictions are more accurate. In contrast to existing studies that use various machine learning methods to estimate the transactions or list prices of real estate properties without separating the building and land prices, this study estimates land price using a large amount of land-use information obtained from various land-and building-related datasets. The random forest and XGBoost methods were used to estimate 52,900 land prices in Seoul, South Korea, from January 2017 to December 2020. The models were also separately trained for different land uses and different time periods. Overall, the results revealed that XGBoost yields a higher prediction accuracy. Whereas the XGBoost models were more accurate on the 2020 data than on the 2017–2020 data when analyzing residential areas, the random forest models were more accurate on the 2017–2020 data than on the 2020 data. Further analysis will extend the prediction model to consider submarkets determined by price volatility and locality.'

# %%
type(abstract_list[0])
# Out:
# str

# %% [markdown]
# # GUARDAR DADOS RECOLHIDOS E PROCESSADOS

# %%
df_results_list.to_csv(path_dados+'search_results.csv',  index=False, encoding = "utf-8")

pd.DataFrame(abstract_list,  columns =['Abstract']).to_csv(path_dados+'search_results_abstracts.csv', index=False, encoding = "utf-8")

# %%
# Save the file
#pickle.dump( df_results_list, file = open(path_dados+"ICD2122_TextMining_DataStructures.pickle", "wb"))

# Reload the file
#test_grouped_df_reloaded = pickle.load(open(path_dados+"ICD2122_TextMining_DataStructures.pickle", "rb"))
